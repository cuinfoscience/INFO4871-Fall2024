# %% [markdown]
# # Web Data Science
# ## Week 02 - XML and JSON
#
# INFO 4871/5871 - Fall 2023
# [Brian C. Keegan, Ph.D.](http://brianckeegan.com/)
# [Assistant Professor, Department of Information Science](https://www.colorado.edu/cmci/people/information-science/brian-c-keegan)
# University of Colorado Boulder
#
# Copyright and distributed under an [MIT License](https://opensource.org/licenses/MIT)

# %% [markdown]
# ## Import libraries

# %%
import requests

# %% [markdown]
# ### XML
#
# The [Extensible Markup Language](https://www.w3.org/XML/) (XML) is a markup language for representing data structures. XML was all the rage at the turn of the century: "many software designers can barely contain their excitement over its potential to establish a real Internet lingua franca" (*The New York Times* in 2000: "[The Next Big Step? It's Called XML](https://www.nytimes.com/2000/06/07/business/the-next-big-leap-it-s-called-xml.html)"). That obviously did not come to pass. But XML remains a robust and open—though verbose—standard for representing structured data.
#
# XML has taken on something of an afterlife as the official data standard for the U.S. Congress. The [House](http://clerk.house.gov/index.aspx) and [Senate](https://www.senate.gov/general/XML.htm) both release information about members, committees, schedules, legislation, and votes in XML. These are immaculately formatted and documented and remarkably up-to-date: the data for members of the 118th Congress are already posted.
#
# ![Congress MemberData XML schema](xml.png)
#
# Use the `requests` library to make a HTTP get request to the House's webserver and get the list of current member data.

# %%
house_raw = requests.get('http://clerk.house.gov/xml/lists/MemberData.xml').text

senate_raw = requests.get('https://www.senate.gov/legislative/LIS_MEMBER/cvc_member_data.xml').text

# %%
house_raw[:1000]
# Out:
# '<?xml version="1.0" encoding="UTF-8"?><MemberData publish-date="September 1, 2023"><title-info><congress-num>118</congress-num><congress-text>One Hundred Eighteenth Congress</congress-text><session>1</session><majority>R</majority><minority>D</minority><clerk>KEVIN F. McCUMBER</clerk><weburl>https://clerk.house.gov</weburl></title-info><members><member><statedistrict>AK00</statedistrict><member-info><namelist>Peltola, Mary</namelist><bioguideID>P000619</bioguideID><lastname>Peltola</lastname><firstname>Mary</firstname><middlename>Sattler</middlename><sort-name>PELTOLA,MARY</sort-name><suffix/><courtesy>Mrs.</courtesy><prior-congress>117</prior-congress><official-name>Mary Sattler Peltola</official-name><formal-name>Mrs. Peltola</formal-name><party>D</party><caucus>D</caucus><state postal-code="AK"><state-fullname>Alaska</state-fullname></state><district>At Large</district><townname>Bethel</townname><office-building>CHOB</office-building><office-room>153</office-room><office-zip>20515</'

# %% [markdown]
# This data is still in a string format (`type(house_raw)`), so it's difficult to search and navigate. Let's make our first soup together using [BeautifulSoup](https://www.crummy.com/software/BeautifulSoup/bs4/doc/).

# %%
# First import the library
from bs4 import BeautifulSoup

# Then make the soup, specifying the "lxml" parser
house_soup = BeautifulSoup(house_raw,'lxml')

# %%
# Try this first
! conda install lxml
# Out:
# Retrieving notices: ...working... done
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.

# %%
# Try this if the first doesn't work
! pip install lxml bs4

# %% [markdown]
# What's so great about this soup-ified string? We now have a suite of new functions and methods that let us navigate the tree. First, let's inspect the different tags/elements in this tree of House member data. This is the full tree of data.

# %%
# Make an empty list to store data
children = []

# Start a loop to go through all the children tags in house_soup
for tag in house_soup.findChildren():
    
    # If the name of the tag (tag.name) is not already in the children list
    if tag.name not in children:
        
        # Add the name of the tag to the children list
        children.append(tag.name)

# Look at the list members
children

# %% [markdown]
# We can navigate through the tree. You won't do this in practice, but it's helpful for debugging. In this case, we navigated from the root node (`html`) into the `body` tag, then the `memberdata` tag, then the `members` tag. There are 441 descendents at this level, corresponding to the 435 voting seats and the 6 seats for territories.

# %%
house_soup.members.member.next_sibling
# Out:
# <member><statedistrict>AL01</statedistrict><member-info><namelist>Carl, Jerry</namelist><bioguideid>C001054</bioguideid><lastname>Carl</lastname><firstname>Jerry</firstname><middlename>L.</middlename><sort-name>CARL,JERRY</sort-name><suffix></suffix><courtesy>Mr.</courtesy><prior-congress>117</prior-congress><official-name>Jerry L. Carl</official-name><formal-name>Mr. Carl</formal-name><party>R</party><caucus>R</caucus><state postal-code="AL"><state-fullname>Alabama</state-fullname></state><district>1st</district><townname>Mobile</townname><office-building>LHOB</office-building><office-room>1330</office-room><office-zip>20515</office-zip><office-zip-suffix>0101</office-zip-suffix><phone>(202) 225-4931</phone><elected-date date="20221108">November  8, 2022</elected-date><sworn-date date="20230107">January  7, 2023</sworn-date></member-info><committee-assignments><committee comcode="AP00" rank="30"></committee><committee comcode="II00" rank="15"></committee><subcommittee rank="8" subcomcode="AP01"></subcommittee><subcommittee rank="7" subcomcode="AP04"></subcommittee><subcommittee rank="7" subcomcode="AP23"></subcommittee><subcommittee rank="9" subcomcode="II13"></subcommittee><subcommittee rank="5" subcomcode="II24"></subcommittee></committee-assignments></member>

# %%
len(house_soup.html.body.memberdata.members)
# Out:
# 441

# %% [markdown]
# You can also short-cut to the members tag directly rather than navigating down the parent elements.

# %%
len(house_soup.members)
# Out:
# 441

# %% [markdown]
# The `.contents` method is great for getting a list of the children below the tag as a list. We can use the `[0]` slice to get the first member and their data in the list. Interestingly, the `<committee-assignments>` tags are currently empty since these have not yet been allocated, but will in the next few weeks.

# %%
house_soup.members.contents[0]
# Out:
# <member><statedistrict>AK00</statedistrict><member-info><namelist>Peltola, Mary</namelist><bioguideid>P000619</bioguideid><lastname>Peltola</lastname><firstname>Mary</firstname><middlename>Sattler</middlename><sort-name>PELTOLA,MARY</sort-name><suffix></suffix><courtesy>Mrs.</courtesy><prior-congress>117</prior-congress><official-name>Mary Sattler Peltola</official-name><formal-name>Mrs. Peltola</formal-name><party>D</party><caucus>D</caucus><state postal-code="AK"><state-fullname>Alaska</state-fullname></state><district>At Large</district><townname>Bethel</townname><office-building>CHOB</office-building><office-room>153</office-room><office-zip>20515</office-zip><office-zip-suffix>0200</office-zip-suffix><phone>(202) 225-5765</phone><elected-date date="20221108">November  8, 2022</elected-date><sworn-date date="20230107">January  7, 2023</sworn-date></member-info><committee-assignments><committee comcode="II00" rank="11"></committee><committee comcode="PW00" rank="25"></committee><subcommittee rank="7" subcomcode="II10"></subcommittee><subcommittee rank="4" subcomcode="II13"></subcommittee><subcommittee rank="11" subcomcode="PW05"></subcommittee><subcommittee rank="5" subcomcode="PW07"></subcommittee></committee-assignments></member>

# %% [markdown]
# You could keep navigating down the tree from here.

# %%
house_soup.members.contents[75]

# %% [markdown]
# Note that this navigation method breaks when the tag has a hyphen in it.

# %%
house_soup.members.contents[75].state-fullname
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 house_soup.members.contents[75].state-fullname
#
# NameError: name 'fullname' is not defined

# %% [markdown]
# Instead you can use the `.find()` method to handle these hyphenated cases.

# %%
house_soup.members.contents[75].find('state-fullname')
# Out:
# <state-fullname>Colorado</state-fullname>

# %% [markdown]
# We can access the text inside the tag with `.text`

# %%
house_soup.members.contents[75].find('state-fullname').text
# Out:
# 'Colorado'

# %% [markdown]
# The `.find_all()` method will be your primary tool when working with structured data. The `<party>` tag codes party membership (D=Democratic, R=Republican) for each representative.

# %%
house_soup.find_all('party')
# Out:
# [<party>D</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party></party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>D</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>,
#  <party>R</party>]

# %% [markdown]
# There [should be](https://en.wikipedia.org/wiki/118th_United_States_Congress#Party_summary) 212 Democrats and 222 Republicans, plus the other non-voting members from territories.

# %%
# Initialize a counter
democrats = 0
republicans = 0
other = 0

# Loop through each element of the caucus tags
for p in house_soup.find_all('party'):
    
    # Check if it's D, R, or something else
    if p.text == "D":
        
        # Increment the appropriate counter
        democrats += 1
    
    elif p.text == "R":
        republicans += 1
        
    else:
        other += 1
        
print("There are {0} Democrats, {1} Republicans, and {2} others in the 118th Congress.".format(democrats,republicans,other))
# Out:
# There are 215 Democrats, 225 Republicans, and 1 others in the 118th Congress.

# %% [markdown]
# ### Exercises
#
# 1. How many members serve in "At Large" districts? (There's at least two ways to do this)
# 2. How many members are women?
# 3. How many members are not incumbents? (They were not in the prior Congress)

# %%
house_soup.members.contents[12]
# Out:
# <member><statedistrict>AQ00</statedistrict><member-info><namelist>Radewagen, Aumua Amata</namelist><bioguideid>R000600</bioguideid><lastname>Radewagen</lastname><firstname>Aumua Amata</firstname><middlename>Coleman</middlename><sort-name>RADEWAGEN,AUMUAAMATA</sort-name><suffix></suffix><courtesy>Mrs.</courtesy><prior-congress>117</prior-congress><official-name>Aumua Amata Coleman Radewagen</official-name><formal-name>Mrs. Radewagen</formal-name><party>R</party><caucus>R</caucus><state postal-code="AS"><state-fullname>American Samoa</state-fullname></state><district>Delegate</district><townname>Pago Pago</townname><office-building>RHOB</office-building><office-room>2001</office-room><office-zip>20515</office-zip><office-zip-suffix>5200</office-zip-suffix><phone>(202) 225-8577</phone><elected-date date="20221108">November  8, 2022</elected-date><sworn-date date="20230107">January  7, 2023</sworn-date></member-info><committee-assignments><committee comcode="FA00" rank="16"></committee><committee comcode="II00" rank="7"></committee><committee comcode="VR00" leadership="Vice Chair" rank="2"></committee><subcommittee rank="6" subcomcode="FA05"></subcommittee><subcommittee rank="3" subcomcode="FA06"></subcommittee><subcommittee rank="5" subcomcode="II13"></subcommittee><subcommittee rank="2" subcomcode="II24"></subcommittee><subcommittee rank="2" subcomcode="VR03"></subcommittee><subcommittee rank="2" subcomcode="VR08"></subcommittee></committee-assignments></member>

# %%
at_large = 0

for district in house_soup.find_all('district'):
    if district.text == 'At Large':
        at_large += 1

at_large
# Out:
# 6

# %%
at_large2 = 0

for district in house_soup.find_all('statedistrict'):
    if district.text[-2:] == '00':
        at_large2 += 1

at_large2
# Out:
# 12

# %%
women = 0

for i in house_soup.find_all('courtesy'):
    if i.text != 'Mr.':
        women += 1

women
# Out:
# 130

# %%
women2 = 0

for i in house_soup.find_all('courtesy'):
    if i.text in ['Mrs.','Miss','Ms.']:
        women2 += 1

women2
# Out:
# 129

# %% [markdown]
# ### JSON
#
# HTML in the wild can be incredibly complicated (which is why we'll dedicate two whole class sessions to it) and XML is verbose and has other ideosyncracies (which is probably why we won't see it after this class). [JavaScript Object Notation](https://www.json.org/) (JSON) is probably the most popular data markup language and is especially ubiquitous when retreiving data from the application programming interfaces (APIs) of popular platforms like Twitter, Reddit, Wikipedia, *etc*.
#
# JSON is attractive for programmers using JavaScript and Python because it can represent a mix of different data types. We need to make a brief digression into Python's fundamental data stuctures in order to understand the contemporary attraction to JSON. Python has a few fundamental data types for representing collections of information:
#
# * **Lists**: This is a basic ordered data structure that can contain strings, ints, and floats.
# * **Dictionaries**: This is an unordered data structure containing key-value pairs, like a phonebook.
#
# Here are some basic examples of lists. Note that lists can contain other lists, and lists of lists of lists, and so on. In this case `school_district` is a list of schools, where each school is a list of classrooms, where each classroom is a list of names.

# %%
# Make classrooms as lists with student names as strings
classroom0 = ['Alice','Bob','Carol','Dave']
classroom1 = ['Eve','Frank','Grace','Harold']
classroom2 = ['Isabel','Jack','Katy','Lloyd']
classroom3 = ['Maria','Nate','Olivia','Philip']
classroom4 = ['Quinn','Rachel','Steve','Terry','Ursula']
classroom5 = ['Violet','Walter','Xavier','Yves','Zoe']

# Make schools that contain classrooms
school0 = [classroom0,classroom1]
school1 = [classroom2,classroom3]
school2 = [classroom4,classroom5]

# Make a school district that contains schools
school_district = [school0,school1,school2]

# Inspect one school's enrollments
school_district
# Out:
# [[['Alice', 'Bob', 'Carol', 'Dave'], ['Eve', 'Frank', 'Grace', 'Harold']],
#  [['Isabel', 'Jack', 'Katy', 'Lloyd'], ['Maria', 'Nate', 'Olivia', 'Philip']],
#  [['Quinn', 'Rachel', 'Steve', 'Terry', 'Ursula'],
#   ['Violet', 'Walter', 'Xavier', 'Yves', 'Zoe']]]

# %% [markdown]
# You can access list elements by their position. In this case, we could access the first name in `classroom0` by requesting the item at the 0th index.

# %%
classroom0[0]
# Out:
# 'Alice'

# %%
school_district[0][0][0]
# Out:
# 'Alice'

# %% [markdown]
# Here are some basic examples of dictionaries. Note that dictionaries can contain other dictionaries, and so on. In this example `mountain_west` is a dictionary of dictionaries where the outer dictionary is keyed by the name of the state and the inner dictionary has different statistical information.

# %%
# Make a dictionary of states containing dictionaries
mountain_west = {
    'Colorado': {
        'Abbreviation': 'CO',
        'Area': 269601,
        'Capital': 'Denver',
        'Established': '1876-08-01',
        'Largest city': 'Denver',
        'Population': 5540545,
        'Representatives': 8
    },
    'Idaho': {
        'Abbreviation': 'ID',
        'Area': 216443,
        'Capital': 'Boise',
        'Established': '1890-07-03',
        'Largest city': 'Boise',
        'Population': 1683140,
        'Representatives': 2
    },
    'Montana': {
        'Abbreviation': 'MT',
        'Area': 380831,
        'Capital': 'Helena',
        'Established': '1889-11-08',
        'Largest city': 'Billings',
        'Population': 1042520,
        'Representatives': 2
    },
    'Utah': {
        'Abbreviation': 'UT',
        'Area': 219882,
        'Capital': 'Salt Lake City',
        'Established': '1896-01-04',
        'Largest city': 'Salt Lake City',
        'Population': 3051217,
        'Representatives': 4
    },
    'Wyoming': {
        'Abbreviation': 'WY',
        'Area': 253335,
        'Capital': 'Cheyenne',
        'Established': '1890-07-10',
        'Largest city': 'Cheyenne',
        'Population': 585501,
        'Representatives': 1
    }
}

# %% [markdown]
# What are the keys and what are the values?

# %%
mountain_west.keys()
# Out:
# dict_keys(['Colorado', 'Idaho', 'Montana', 'Utah', 'Wyoming'])

# %%
mountain_west.values()
# Out:
# dict_values([{'Abbreviation': 'CO', 'Area': 269601, 'Capital': 'Denver', 'Established': '1876-08-01', 'Largest city': 'Denver', 'Population': 5540545, 'Representatives': 8}, {'Abbreviation': 'ID', 'Area': 216443, 'Capital': 'Boise', 'Established': '1890-07-03', 'Largest city': 'Boise', 'Population': 1683140, 'Representatives': 2}, {'Abbreviation': 'MT', 'Area': 380831, 'Capital': 'Helena', 'Established': '1889-11-08', 'Largest city': 'Billings', 'Population': 1042520, 'Representatives': 2}, {'Abbreviation': 'UT', 'Area': 219882, 'Capital': 'Salt Lake City', 'Established': '1896-01-04', 'Largest city': 'Salt Lake City', 'Population': 3051217, 'Representatives': 4}, {'Abbreviation': 'WY', 'Area': 253335, 'Capital': 'Cheyenne', 'Established': '1890-07-10', 'Largest city': 'Cheyenne', 'Population': 585501, 'Representatives': 1}])

# %% [markdown]
# You access dictionary values by their keys.

# %%
# Statistics about Colorado
mountain_west['Colorado']
# Out:
# {'Abbreviation': 'CO',
#  'Area': 269601,
#  'Capital': 'Denver',
#  'Established': '1876-08-01',
#  'Largest city': 'Denver',
#  'Population': 5540545,
#  'Representatives': 8}

# %% [markdown]
# What is the population of Colorado? In a dictionary of dictionaries, you can access the inner dictionary with another key.

# %%
mountain_west['Colorado']['Population']
# Out:
# 5540545

# %% [markdown]
# Nested data structures do not need to be the same type. A dictionary can have a list as a value for example. This would probably make the `school_district` example easier to understand.

# %%
school_district_dict = {
    'School 1':{
        'Classroom A':['Alice','Bob','Carol','Dave'],
        'Classroom B':['Eve','Frank','Grace','Harold']
    },
    'School 2':{
        'Classroom A':['Isabel','Jack','Katy','Lloyd'],
        'Classroom B':['Maria','Nate','Olivia','Philip']
    },
    'School 3':{
        'Classroom A':['Quinn','Rachel','Steve','Terry','Ursula'],
        'Classroom B':['Violet','Walter','Xavier','Yves','Zoe']
    }
}

# %% [markdown]
# We can access the 3rd member (remember Python indexes start at 0, so we ask for 2) of "Classroom B" in "School 2" by working our way outside inward.

# %%
school_district_dict['School 2']['Classroom B'][2]
# Out:
# 'Olivia'

# %% [markdown]
# A list can take just about any other data structure as a value. Dictionaries are great because they label your data for you but don't preserve order and need unique keys, so they're bad at storing repeated data like a time series. Here's a list where the values are dictionaries and each dictionary is information about the population, state, and year of a location.

# %%
state_population = [ 
    {'Population': 4338785, 'State': 'Colorado', 'Year': 2000},
    {'Population': 4444513, 'State': 'Colorado', 'Year': 2001},
    {'Population': 4504709, 'State': 'Colorado', 'Year': 2002},
    {'Population': 4555084, 'State': 'Colorado', 'Year': 2003},
    {'Population': 4608811, 'State': 'Colorado', 'Year': 2004},
    {'Population': 4662534, 'State': 'Colorado', 'Year': 2005},
    {'Population': 4745660, 'State': 'Colorado', 'Year': 2006},
    {'Population': 4821784, 'State': 'Colorado', 'Year': 2007},
    {'Population': 4901938, 'State': 'Colorado', 'Year': 2008},
    {'Population': 4976853, 'State': 'Colorado', 'Year': 2009},
    {'Population': 5049935, 'State': 'Colorado', 'Year': 2010},
    {'Population': 5119538, 'State': 'Colorado', 'Year': 2011},
    {'Population': 5191086, 'State': 'Colorado', 'Year': 2012},
    {'Population': 5268413, 'State': 'Colorado', 'Year': 2013},
    {'Population': 5350118, 'State': 'Colorado', 'Year': 2014},
    {'Population': 5448055, 'State': 'Colorado', 'Year': 2015},
    {'Population': 5538180, 'State': 'Colorado', 'Year': 2016}
]

# %% [markdown]
# What's the population of Colorado in 2008?
#
# It's actually a small pain to get it out in this list of dictionaries format. You could loop through each dictionary in the list and ask if its "Year" in 2008 and only then print out its "Population". You could discover the min and max years (assuming the data is reliably chronological) and then calculate the index where 2008 should occur. This format probably starts to remind you of some of the limitations of XML, but it has strengths in some situations.

# %%
# Loop through each dictionary in the list
for year_data in state_population:
    
    # If the inner dictionary's value for "Year" is 2008, do something, otherwise skip
    if year_data['Year'] == 2008:
        
        # Print our the inner dictionary's value for "Population"
        print(year_data['Population'])
# Out:
# 4901938

# %%
# Year 2000 is at index 0, so year 2008 should be at index 8
# Passing only the index 8 returns a dictionary
# Include the key whose value you want from this dictionary: "Population"
state_population[8]['Population']
# Out:
# 4901938

# %% [markdown]
# ### Exercises
#
# Below is an example of a [tweet status](https://dev.twitter.com/overview/api/tweets) object that Twitter's [API returns](https://dev.twitter.com/rest/reference/get/statuses/show/id). This `obama_tweet` dictionary corresponds to [this tweet](https://twitter.com/BarackObama/status/831527113211645959). This is a classic example of a JSON object containing a mixture of dictionaries, lists, lists of dictionaries, dictionaries of lists, *etc*.

# %%
obama_tweet = {
    'created_at': 'Tue Feb 14 15:34:47 +0000 2017',
    'favorite_count': 1023379,
    'hashtags': [],
    'id': 831527113211645959,
    'id_str': '831527113211645959',
    'lang': 'en',
    'media': [
        {
            'display_url': 'pic.twitter.com/O0UhJWoqGN',
            'expanded_url': 'https://twitter.com/BarackObama/status/831527113211645959/photo/1',
            'id': 831526916398149634,
            'media_url': 'http://pbs.twimg.com/media/C4otUykWcAIbSy1.jpg',
            'media_url_https': 'https://pbs.twimg.com/media/C4otUykWcAIbSy1.jpg',
            'sizes': {
                'large': {'h': 800, 'resize': 'fit', 'w': 1200},
                'medium': {'h': 800, 'resize': 'fit', 'w': 1200},
                'small': {'h': 453, 'resize': 'fit', 'w': 680},
                'thumb': {'h': 150, 'resize': 'crop', 'w': 150}
            },
         'type': 'photo',
         'url': 'https://t.co/O0UhJWoqGN'
        }
    ],
    'retweet_count': 252266,
    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
    'text': 'Happy Valentine’s Day, @michelleobama! Almost 28 years with you, but it always feels new. https://t.co/O0UhJWoqGN',
    'urls': [],
    'user': {
        'created_at': 'Mon Mar 05 22:08:25 +0000 2007',
        'description': 'Dad, husband, President, citizen.',
        'favourites_count': 10,
        'followers_count': 84814791,
        'following': True,
        'friends_count': 631357,
        'id': 813286,
        'lang': 'en',
        'listed_count': 221906,
        'location': 'Washington, DC',
        'name': 'Barack Obama',
        'profile_background_color': '77B0DC',
        'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/451819093436268544/kLbRvwBg.png',
        'profile_banner_url': 'https://pbs.twimg.com/profile_banners/813286/1484945688',
        'profile_image_url': 'http://pbs.twimg.com/profile_images/822547732376207360/5g0FC8XX_normal.jpg',
        'profile_link_color': '2574AD',
        'profile_sidebar_fill_color': 'C2E0F6',
        'profile_text_color': '333333',
        'screen_name': 'BarackObama',
        'statuses_count': 15436,
        'time_zone': 'Eastern Time (US & Canada)',
        'url': 'https://t.co/93Y27HEnnX',
        'utc_offset': -18000,
        'verified': True},
    'user_mentions': [
        {'id': 409486555,
         'name': 'Michelle Obama',
         'screen_name': 'MichelleObama'}
    ]
}

# %% [markdown]
# 1. What are the top-most keys in the `obama_tweet` object?
# 2. When was this tweet sent?
# 3. Does this tweet mention anyone?
# 4. How many retweets did this tweet receive (at the time I collected it)?
# 5. How many followers does the "user" who wrote this tweet have?
# 6. What's the "media_url" for the image in this tweet?

# %%
obama_tweet.keys()
# Out:
# dict_keys(['created_at', 'favorite_count', 'hashtags', 'id', 'id_str', 'lang', 'media', 'retweet_count', 'source', 'text', 'urls', 'user', 'user_mentions'])

# %%
obama_tweet['created_at']
# Out:
# 'Tue Feb 14 15:34:47 +0000 2017'

# %%
obama_tweet['user_mentions'][0]['screen_name']
# Out:
# 'MichelleObama'

# %%
obama_tweet['retweet_count']
# Out:
# 252266

# %%
obama_tweet['media'][0]['media_url']
# Out:
# 'http://pbs.twimg.com/media/C4otUykWcAIbSy1.jpg'

# %% [markdown]
# ## Show-and-tell
#
# For Thursday, come to class with examples of the following for show-and-tell.

# %% [markdown]
# ### Parse the XML of an RSS feed
#
# [Really Simple Syndication](https://en.wikipedia.org/wiki/RSS) (RSS) is a format for serving webfeeds commonly used for blogs and for podcasts.
#
# 1. Find the RSS feed for a blog, podcast, or some other online property. For example, *This American Life* hosts its RSS feed [here](http://feed.thisamericanlife.org/talpodcast).
# 2. Use `requests` to import the RSS feed into your notebook.
# 3. Review the ontology of the RSS. What are some interesting objects?
# 4. Use `BeautifulSoup` to parse the raw XML.
# 5. Do some kind of exploratory data analysis.

# %%
rss_raw = requests.get('http://feed.thisamericanlife.org/talpodcast').text
rss_raw
# Out:
# '<?xml version="1.0" encoding="utf-8"?>\n<rss version="2.0" xml:base="https://www.thisamericanlife.org"  xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:itunes="http://www.itunes.com/dtds/podcast-1.0.dtd">\n<channel>\n <title>This American Life</title>\n <link>https://www.thisamericanlife.org</link>\n <description>Each week we choose a theme. Then anything can happen. This American Life is true stories that unfold like little movies for radio. Personal stories with funny moments, big feelings, and surprising plot twists. Newsy stories that try to capture what it’s like to be alive right now. It’s the most popular weekly podcast in the world, and winner of the first ever Pulitzer Prize for a radio show or podcast. Hosted by Ira Glass and produced in collaboration with WBEZ Chicago.</description>\n <language>en</language>\n <itunes:new-feed-url>https://www.thisamericanlife.org/podcast/rss.xml</itunes:new-feed-url>\n <copyright>Copyright 1995-2023 This American Life</copyright>\n <itunes:author>This American Life</itunes:author>\n <itunes:subtitle>Each week we choose a theme. Then anything can happen. This American Life is true stories that unfold like little movies for radio. Personal stories with funny moments, big feelings, and surprising plot twists. Newsy stories that try to capture what it’s like to be alive right now. It’s the most popular weekly podcast in the world, and winner of the first ever Pulitzer Prize for a radio show or podcast. Hosted by Ira Glass and produced in collaboration with WBEZ Chicago.</itunes:subtitle>\n <itunes:owner> <itunes:email>rich@thislife.org</itunes:email>\n</itunes:owner>\n <itunes:category text="Society &amp; Culture" />\n <itunes:category text="Arts" />\n <itunes:category text="News"> <itunes:category text="Politics" />\n</itunes:category>\n <itunes:image href="https://files.thisamericanlife.org/sites/all/themes/thislife/img/tal-name-1400x1400.png" />\n<item>\n <title>388: Rest Stop</title>\n <link>https://www.thisamericanlife.org/388/rest-stop</link>\n <description>&lt;p&gt;Nine radio reporters. Two days. One rest stop on the New York State Thruway. Stories of people who are just passing through, and the ones who can’t leave, because this is where their jobs are.\n&lt;/p&gt;&lt;ul&gt;&lt;li&gt;Act One: Host Ira Glass describes scenes from a rest stop on the New York State Thruway, the Plattekill Travel Plaza, and the kind of people you might meet if you ever stayed long enough to talk with them. These include Robert Woodhill, the general manager, who needs a good sales day so he can beat his friend Andy, who manages a rest stop in Maine, in their weekly competition. Ira hangs out with a group of foreign students who’ve landed in Plattekill on a summer work program, and reporter Lisa Pollak gets travel tips from Lenny Wheat, who works at the rest stop’s information booth. Reporter Jonathan Goldstein spends a few hours in the rest stop parking lot. (30 minutes)&lt;/li&gt;&lt;li&gt;Act Two: More stories of travelers and workers at a highway rest stop. The competition between Plattekill and Maine continues. Reporter Sean Cole observes the lunch rush at the rest stop’s busiest restaurant and stumbles into a behind-the-scenes romance. Reporter Gregory Warner watches a cashier at the Travel Mart deal with an angry customer. Reporters Nancy Updike and Jay Allison hang out for the graveyard shift – midnight to 8 a.m. – and find a surprising amount of romance at the rest stop. (26 \xa0minutes)&lt;/li&gt;&lt;/ul&gt;&lt;p&gt;Transcripts are available at &lt;a href=&quot;https://www.thisamericanlife.org/388/transcript&quot;&gt;thisamericanlife.org&lt;/a&gt;&lt;/p&gt;</description>\n <pubDate>Sun, 03 Sep 2023 18:00:00 -0400</pubDate>\n <guid isPermaLink="false">37285 at https://www.thisamericanlife.org</guid>\n <itunes:author>This American Life</itunes:author>\n <enclosure url="https://pfx.vpixl.com/6qj4J/dts.podtrac.com/redirect.mp3/chtbl.com/track/8DB4DB/pdst.fm/e/nyt.simplecastaudio.com/bbbcc290- ...

# %% [markdown]
# ### Parse the JSON returned from Wikipedia
#
# Wikipedia serves up data about its articles from its API ([docs](https://www.mediawiki.org/wiki/API:Revisions)) using JSON. `wikipedia_500_recent_revisions` a simple function that will retrieve the 500 most recent revisions for an English Wikipedia article.
#
# 1. Use the function to retrieve the most recent revisions for an English Wikipedia article.
# 2. Navigate to the part of JSON document where the "revisions" lists lives.
# 3. Count the number of revisions in the list. If you have 500 revisions, come up with a hypothesis about what the "rvcontinue" parameter might mean.
# 4. Find the user who made the most contributions in your data.

# %%
def wikipedia_500_recent_revisions(page_title):    
    
    query_params = {
        'action':'query',
        'titles':page_title,
        'prop':'revisions',
        'rvprop':'ids|userid|comment|timestamp|user|size|sha1',
        'rvlimit':500,
        'rvdir':'older',
        'format':'json'
    }
    
    return requests.get(url = "https://en.wikipedia.org/w/api.php", params = query_params).json()

# %%
revisions_json = wikipedia_500_recent_revisions('Deion Sanders')
revisions_json
# Out:
# {'continue': {'rvcontinue': '20220915081648|1110408711', 'continue': '||'},
#  'query': {'pages': {'901141': {'pageid': 901141,
#     'ns': 0,
#     'title': 'Deion Sanders',
#     'revisions': [{'revid': 1173981510,
#       'parentid': 1173962812,
#       'user': 'Bmitchelf',
#       'userid': 1336244,
#       'timestamp': '2023-09-05T15:10:34Z',
#       'size': 90827,
#       'sha1': '14715df8f0a0fdf22ae1452f965e184a012ba0f3',
#       'comment': '/* Personal life */ son playing in Colorado'},
#      {'revid': 1173962812,
#       'parentid': 1173903846,
#       'user': 'Tundraspalace',
#       'userid': 19022170,
#       'timestamp': '2023-09-05T12:44:09Z',
#       'size': 90042,
#       'sha1': 'fcbfa15bb9d17a1655958741d9e7f3f3579eb1af',
#       'comment': '/* Dallas Cowboys */'},
#      {'revid': 1173903846,
#       'parentid': 1173898101,
#       'user': 'FrescoBot',
#       'userid': 9021902,
#       'timestamp': '2023-09-05T03:33:45Z',
#       'size': 90019,
#       'sha1': 'a27d33ee4abb94f20423d3b749f674099023c801',
#       'comment': 'Bot: [[User:FrescoBot/Links|link syntax]] and minor changes'},
#      {'revid': 1173898101,
#       'parentid': 1173895061,
#       'user': 'Puritan-Monergist',
#       'userid': 12538458,
#       'timestamp': '2023-09-05T02:39:36Z',
#       'size': 89938,
#       'sha1': '654f61efeaa25fd86eac3c981a43daee2291c4e7',
#       'comment': ''},
#      {'revid': 1173895061,
#       'parentid': 1173745213,
#       'user': 'Singh117',
#       'userid': 18055708,
#       'timestamp': '2023-09-05T02:14:18Z',
#       'size': 89925,
#       'sha1': '089d38061c9d7358a830d531d97e057204db5dbf',
#       'comment': '/* Personal life */Clarified the 2013 assault incident'},
#      {'revid': 1173745213,
#       'parentid': 1173743883,
#       'user': '2603:7080:A03E:E800:C976:1516:8AE5:C765',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2023-09-04T04:40:00Z',
#       'size': 89796,
#       'sha1': '6e10d5863266dac1270d66a38f31a043eccb3d6a',
#       'comment': ''},
#      {'revid': 1173743883,
#       'parentid': 1173743822,
#       'user': 'Bojo1498',
#       'userid': 19595349,
#       'timestamp': '2023-09-04T04:27:59Z',
#       'size': 89681,
#       'sha1': 'ca5a93504fcbd976ccc3896a4a8262ecbdb1f830',
#       'comment': 'Reverted 1 edit by [[Special:Contributions/47.196.0.230|47.196.0.230]] ([[User talk:47.196.0.230|talk]]): Unsourced'},
#      {'revid': 1173743822,
#       'parentid': 1173742020,
#       'user': '47.196.0.230',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2023-09-04T04:27:27Z',
#       'size': 89688,
#       'sha1': 'fff761d6200e050e681ecc768f96d7cc4f5dd889',
#       'comment': ''},
#      {'revid': 1173742020,
#       'parentid': 1173741926,
#       'user': 'Bojo1498',
#       'userid': 19595349,
#       'timestamp': '2023-09-04T04:14:47Z',
#       'size': 89681,
#       'sha1': 'ca5a93504fcbd976ccc3896a4a8262ecbdb1f830',
#       'comment': 'Reverted 1 edit by [[Special:Contributions/24.40.235.71|24.40.235.71]] ([[User talk:24.40.235.71|talk]]) to last revision by Bojo1498'},
#      {'revid': 1173741926,
#       'parentid': 1173741772,
#       'user': '24.40.235.71',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2023-09-04T04:14:08Z',
#       'size': 89681,
#       'sha1': '673a0385c8e58065662bfd5d4dc23293afbf13a8',
#       'comment': ''},
#      {'revid': 1173741772,
#       'parentid': 1173741704,
#       'user': 'Bojo1498',
#       'userid': 19595349,
#       'timestamp': '2023-09-04T04:13:00Z',
#       'size': 89681,
#       'sha1': 'ca5a93504fcbd976ccc3896a4a8262ecbdb1f830',
#       'comment': 'Reverted 1 edit by [[Special:Contributions/24.40.235.71|24.40.235.71]] ([[User talk:24.40.235.71|talk]]) to last revision by ClueBot NG'},
#      {'revid': 1173741704,
#       'parentid': 1173737287,
#       'user': '24.40.235.71',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2023-09-04T04:12:26Z',
#       'size': 89682,
#       'sha1': '7edf5190ce75ef67efbdea03d35de57026c9c6b8',
#       'comment': ''},
#      {'revid': 1173737287,
#       'parentid': 1173737229,
#       'user': 'ClueBot NG',
#       'userid': 13286072,
#       'timestamp': '2023-09-04T03:30:32Z',
#       'size': 89681,
#       'sha1': 'ca5a93504fcbd976ccc3896a4a8262ecbdb1f830',
#       'comment': 'Reverting possible vandalism by [[Special:Contribs/Blockingevasionnumber|Blockingevasionnumber]] to version by Bojo1498. [[WP:CBFP|Report False Positive?]] Thanks, [[WP:CBNG|ClueBot NG]]. (4266025) (Bot)'},
#      {'revid': 1173737229,
#       'parentid': 1173737118,
#       'user': 'Blockingevasionnumber',
#       'userid': 46493347,
#       'timestamp': '2023-09-04T03:30:03Z',
#       'size': 89695,
#       'sha1': '10218f91d93ae42998662cfe020604368e393cb4',
#       'comment': ''},
#      {'revid': 1173737118,
#       'parentid': 1173737076,
#       'user': 'Bojo1498',
#       'userid': 19595349,
#       'timestamp': '2023-09-04T03:29:06Z',
#       'size': 89681,
#       'sha1': 'ca5a93504fcbd976ccc3896a4a8262ecbdb1f830',
#       'comment': 'Reverted 2 edits by [[Special:Contributions/Blockingevasionnumber|Blockingevasionnumber]] ([[User talk:Blockingevasionnumber|talk]]): Unsourced birthday change'},
#      {'revid': 1173737076,
#       'parentid': 1173737028,
#       'user': 'Blockingevasionnumber',
#       'userid': 46493347,
#       'timestamp': '2023-09-04T03:28:41Z',
#       'size': 89681,
#       'sha1': '8f6538cf5415aa72a4e15c232c627dabf8c8d204',
#       'comment': ''},
#      {'revid': 1173737028,
#       'parentid': 1173724871,
#       'user': 'Blockingevasionnumber',
#       'userid': 46493347,
#       'timestamp': '2023-09-04T03:28:11Z',
#       'size': 89681,
#       'sha1': '019f7625550f4e5ac5035d5986021341e2b558a2',
#       'comment': ''},
#      {'revid': 1173724871,
#       'parentid': 1173704731,
#       'user': '2603:8081:7C09:309:812:F32:BB47:EB19',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2023-09-04T01:51:32Z',
#       'size': 89681,
#       'sha1': 'ca5a93504fcbd976ccc3896a4a8262ecbdb1f830',
#       'comment': ''},
#      {'revid': 1173704731,
#       'parentid': 1173618705,
#       'user': '2600:4040:243B:EF00:B4FD:FA8C:3948:3BC7',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2023-09-03T23:27:36Z',
#       'size': 89688,
#       'sha1': 'fff761d6200e050e681ecc768f96d7cc4f5dd889',
#       'comment': ''},
#      {'revid': 1173618705,
#       'parentid': 1173603803,
#       'user': 'Coltsfan',
#       'userid': 8560991,
#       'timestamp': '2023-09-03T15:19:03Z',
#       'size': 89681,
#       'sha1': 'ca5a93504fcbd976ccc3896a4a8262ecbdb1f830',
#       'comment': '/* Colorado */'},
#      {'revid': 1173603803,
#       'parentid': 1173542535,
#       'user': 'Wayne',
#       'userid': 25058459,
#       'timestamp': '2023-09-03T13:48:09Z',
#       'size': 89797,
#       'sha1': '3cda44f9532d84e426c9dbbab2c8d2e9cacab271',
#       'comment': '/* Personal life */'},
#      {'revid': 1173542535,
#       'parentid': 1173518596,
#       'user': '2600:1700:B590:24A0:44D1:1EB8:98ED:DF95',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2023-09-03T03:22:51Z',
#       'size': 89781,
#       'sha1': 'e7db4d13bc42d0d7f38fdd1158b796f21abf21d9',
#       'comment': 'Updated education.'},
#      {'revid': 1173518596,
#       'parentid': 1173518431,
#       'user': 'Sumanuil',
#       'userid': 31876559,
#       'timestamp': '2023-09-02T23:34:57Z',
#       'size': 89788,
#       'sha1': '325159ee1049d098067279da58577147fa46fc96',
#       'comment': 'Undid revision 1173517476 by [[Special:Contributions/2600:1004:B21F:D52A:1C68:DA25:B42D:190A|2600:1004:B21F:D52A:1C68:DA25:B42D:190A]] ([[User talk:2600:1004:B21F:D52A:1C68:DA25:B42D:190A|talk]])'},
#      {'revid': 1173518431,
#       'parentid': 1173518213,
#       'user': '2600:6C67:157F:C769:50DE:4ABE:FBFA:B5A9',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2023-09-02T23:33:15Z',
#       'size': 89772,
#       'sha1': '64969c6f4dba0b7c81e1195789fa262adfc96e34',
#       'comment': ''},
#      {'revid': 1173518213,
#       'parentid': 1173517476,
#       'user': '2600:6C67:157F:C769:50DE:4ABE:FBFA:B5A9',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2023-09-02T23:30:48Z',
#       'size': 89764,
#       'sha1': '05e5c89d0fadfecb1d74335f65c04f9021d64b33',
#       'comment': 'fixed colorado reference to university of colorado'},
#      {'revid': 1173517476,
#       'parentid': 1173512214,
#       'user': '2600:1004:B21F:D52A:1C68:DA25:B42D:190A',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2023-09-02T23:22:43Z',
#       'size': 89742,
#       'sha1': '1ab9bde59bafa251e9ee598a029b43c21bedc4fd',
#       'comment': '/* College career */'},
#      {'revid': 1173512214,
#       'parentid': 1173491979,
#       'user': '209.191.1.6',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2023-09-02T22:33:43Z',
#       'size': 89758,
#       'sha1': '0b6d25a206c0d5352706c8645517ea47ecc63814',
#       'comment': '/* Colorado */'},
#      {'revid': 1173491979,
#       'parentid': 1173491872,
#       'user': 'AbelAndCain',
#       'userid': 38805863,
#       'timestamp': '2023-09-02T19:45:24Z',
#       'size': 89642,
#       'sha1': '3f6f889c17a8a55fab1bf48a779bf2145ebf50d8',
#       'comment': 'Updated page.'},
#      {'revid': 1173491872,
#       'parentid': 1173489294,
#       'user': 'AbelAndCain',
#       'userid': 38805863,
#       'timestamp': '2023-09-02T19:44:41Z',
#       'size': 89642,
#       'sha1': 'd68db8fe27b876c7a936e0e28b2b632503b47f00',
#       'comment': '/* Head coaching record */Updated page'},
#      {'revid': 1173489294,
#       'parentid': 1173489069,
#       'user': 'CUA 27',
#       'userid': 25708940,
#       'timestamp': '2023-09-02T19:23:52Z',
#       'size': 89642,
#       'sha1': '310df296b068689a58d7704715b0ab9a7307c9ed',
#       'comment': '/* Jackson State */ copyedit'},
#      {'revid': 1173489069,
#       'parentid': 1173463112,
#       'user': 'CUA 27',
#       'userid': 25708940,
#       'timestamp': '2023-09-02T19:22:01Z',
#       'size': 89658,
#       'sha1': 'df3525510603e86a0c3bd5eb6c59b4536b239424',
#       'comment': 'He no longer plays. Tracks the language of the lead sentence.'},
#      {'revid': 1173463112,
#       'parentid': 1173461909,
#       'user': '2601:100:C180:E40:DC3B:69BB:E53:CBB4',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2023-09-02T16:03:11Z',
#       'size': 89651,
#       'sha1': '5a83296251e7d936184c608b831b71d3d882bd4f',
#       'comment': ''},
#      {'revid': 1173461909,
#       'parentid': 1173448797,
#       'user': 'Glacier109',
#       'userid': 736847,
#       'timestamp': '2023-09-02T15:54:07Z',
#       'size': 89644,
#       'sha1': '6774b0242bf133ae30d7a0c4c5678ef6528299e0',
#       'comment': '/* Legacy and honors */'},
#      {'revid': 1173448797,
#       'parentid': 1173448734,
#       'user': '--WikiUser1234945--',
#       'userid': 44690822,
#       'timestamp': '2023-09-02T14:00:26Z',
#       'size': 89480,
#       'sha1': 'c13c3ed81de43e524bfde48f7c1761a46df51039',
#       'comment': 'Reverted edits by [[Special:Contributions/2600:6C58:637F:A23C:F7FC:683D:EBB:4F5|2600:6C58:637F:A23C:F7FC:683D:EBB:4F5]] ([[User talk:2600:6C58:637F:A23C:F7FC:683D:EBB:4F5|talk]]) ([[WP:HG|HG]]) (3.4.12)'},
#      {'revid': 1173448734,
#       'parentid': 1173288862,
#       'user': '2600:6C58:637F:A23C:F7FC:683D:EBB:4F5',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2023-09-02T13:59:59Z',
#       'size': 89479,
#       'sha1': 'b3e1764863ca8df286cc4d75ce1b53a6ad7d9b3a',
#       'comment': ''},
#      {'revid': 1173288862,
#       'parentid': 1173080525,
#       'user': '73.42.15.124',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2023-09-01T13:47:25Z',
#       'size': 89480,
#       'sha1': 'c13c3ed81de43e524bfde48f7c1761a46df51039',
#       'comment': '/* San Francisco 49ers */Removed sensationalism'},
#      {'revid': 1173080525,
#       'parentid': 1173080391,
#       'user': 'Meters',
#       'userid': 3632083,
#       'timestamp': '2023-08-31T04:04:11Z',
#       'size': 89530,
#       'sha1': 'e5db5a8f3c805ed3376f9c7fb0d01d711162af3a',
#       'comment': 'Undid revision 1173033929 by [[Special:Contributions/65.191.159.95|65.191.159.95]] ([[User talk:65.191.159.95|talk]])'},
#      {'revid': 1173080391,
#       'parentid': 1173063007,
#       'user': 'Meters',
#       'userid': 3632083,
#       'timestamp': '2023-08-31T04:02:35Z',
#       'size': 89537,
#       'sha1': '09b9e6305f9eef587e1499e0dcaae7836774c1ff',
#       'comment': 'Reverted edit by [[Special:Contribs/2601:4C1:4000:8190:AD59:4374:4DE7:CD8A|2601:4C1:4000:8190:AD59:4374:4DE7:CD8A]] ([[User talk:2601:4C1:4000:8190:AD59:4374:4DE7:CD8A|talk]]) to last version by 65.191.159.95'},
#      {'revid': 1173063007,
#       'parentid': 1173033929,
#       'user': '2601:4C1:4000:8190:AD59:4374:4DE7:CD8A',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2023-08-31T01:21:27Z',
#       'size': 89464,
#       'sha1': 'e17ce1bf8d4b853c9d067b8b7782a31b7b5efab8',
#       'comment': ''},
#      {'revid': 1173033929,
#       'parentid': 1170821793,
#       'user': '65.191.159.95',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2023-08-30T21:36:30Z',
#       'size': 89537,
#       'sha1': '09b9e6305f9eef587e1499e0dcaae7836774c1ff',
#       'comment': ''},
#      {'revid': 1170821793,
#       'parentid': 1170745198,
#       'user': 'Caro7200',
#       'userid': 36838435,
#       'timestamp': '2023-08-17T12:12:31Z',
#       'size': 89530,
#       'sha1': 'e5db5a8f3c805ed3376f9c7fb0d01d711162af3a',
#       'comment': '/* Drafts and minor leagues */'},
#      {'revid': 1170745198,
#       'parentid': 1170734539,
#       'user': 'Ira Leviton',
#       'userid': 25046916,
#       'timestamp': '2023-08-16T23:29:33Z',
#       'size': 89541,
#       'sha1': 'eaafd0c6726916ce853f9e9d3cb125780788c0d6',
#       'comment': 'Fixed references.  Please see [[Category:CS1 errors: unsupported parameter]] and [[Wikipedia:Manual of Style/Capital letters#All caps]].'},
#      {'revid': 1170734539,
#       'parentid': 1168955935,
#       'user': '2603:80A0:109:632:8108:4E20:C7BA:DA40',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2023-08-16T21:59:18Z',
#       'size': 89541,
#       'sha1': '09c6efa0cc3c34d1f2b45ae70857d2d2923838f4',
#       'comment': '/* Jackson State */'},
#      {'revid': 1168955935,
#       'parentid': 1168955821,
#       'user': '2601:19E:4180:6D50:65F5:930C:B0B2:CD63',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2023-08-06T04:07:51Z',
#       'size': 88827,
#       'sha1': '8fc0d488ea93534cbed4892fc2ed0387fb840a07',
#       'comment': 'rvv'},
#      {'revid': 1168955821,
#       'parentid': 1168955594,
#       'user': '2600:1700:5B24:2050:51F7:9E00:C37B:A8CC',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2023-08-06T04:06:58Z',
#       'size': 88826,
#       'sha1': 'f266c0c6e70ed971534d63ba3ce318f38e987188',
#       'comment': ''},
#      {'revid': 1168955594,
#       'parentid': 1168908335,
#       'user': '2600:1700:5B24:2050:51F7:9E00:C37B:A8CC',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2023-08-06T04:05:05Z',
#       'size': 88825,
#       'sha1': '5cb7c26cf2cb7edd481149dcbf3d5d883792cd5c',
#       'comment': ''},
#      {'revid': 1168908335,
#       'parentid': 1168587978,
#       'user': 'Yankees10',
#       'userid': 4268551,
#       'timestamp': '2023-08-05T21:03:15Z',
#       'size': 88827,
#       'sha1': '8fc0d488ea93534cbed4892fc2ed0387fb840a07',
#       'comment': '/* Professional baseball career */ redundant'},
#      {'revid': 1168587978,
#       'parentid': 1168123151,
#       'user': '50.86.89.162',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2023-08-03T18:33:23Z',
#       'size': 88931,
#       'sha1': '289f94dd6600eece12d94cce184913b0cb233054',
#       'comment': '/* College career */'},
#      {'revid': 1168123151,
#       'parentid': 1167806293,
#       'user': '47.36.41.227',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2023-07-31T23:29:42Z',
#       'size': 88931,
#       'sha1': '335adf640f01e62986c2746fdf44a71acdb1495b',
#       'comment': ''},
#      {'revid': 1167806293,
#       'parentid': 1167806222,
#       'user': 'Josve05a',
#       'userid': 12023796,
#       'timestamp': '2023-07-30T00:20:05Z',
#       'size': 88902,
#       'sha1': 'e20e3b9a661bdb78d4afd76efe591a7273b7cda2',
#       'comment': 'Reverted edits by [[Special:Contributions/2600:4040:20ED:6600:C82A:A1DA:AD0F:77A5|2600:4040:20ED:6600:C82A:A1DA:AD0F:77A5]] ([[User talk:2600:4040:20ED:6600:C82A:A1DA:AD0F:77A5|talk]]): [[WP:NOR|original research]] ([[WP:HG|HG]]) (3.4.12)'},
#      {'revid': 1167806222,
#       'parentid': 1166182752,
#       'user': '2600:4040:20ED:6600:C82A:A1DA:AD0F:77A5',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2023-07-30T00:19:35Z',
#       'size': 88978,
#       'sha1': 'ab8fb707b19871dd656f207a99f297ea9bdb69ac',
#       'comment': ''},
#      {'revid': 1166182752,
#       'parentid': 1165632755,
#       'user': 'CNC33',
#       'userid': 421149,
#       'timestamp': '2023-07-19T21:50:57Z',
#       'size': 88902,
#       'sha1': 'e20e3b9a661bdb78d4afd76efe591a7273b7cda2',
#       'comment': '/* Personal life */'},
#      {'revid': 1165632755,
#       'parentid': 1165632575,
#       'user': 'Jevansen',
#       'userid': 2842084,
#       'timestamp': '2023-07-16T12:15:22Z',
#       'size': 88483,
#       'sha1': 'c20b067ec5b07e2879ef3a574492f06ebbda40bc',
#       'comment': 'Removing from [[Category:Players of American football from Florida]] using [[c:Help:Cat-a-lot|Cat-a-lot]]'},
#      {'revid': 1165632575,
#       'parentid': 1165130534,
#       'user': 'Jevansen',
#       'userid': 2842084,
#       'timestamp': '2023-07-16T12:14:07Z',
#       'size': 88538,
#       'sha1': '56c8fde0870383cfb3234f948e0ab68cd4ed7e24',
#       'comment': 'Copying from [[Category:Sportspeople from Fort Myers, Florida]] to [[Category:Players of American football from Lee County, Florida]] using [[c:Help:Cat-a-lot|Cat-a-lot]]'},
#      {'revid': 1165130534,
#       'parentid': 1164107208,
#       'user': 'DaveTheBrave',
#       'userid': 31952441,
#       'timestamp': '2023-07-13T05:28:10Z',
#       'size': 88471,
#       'sha1': '21dade83144b55c4c6b9003c8a986f9361dd4f6f',
#       'comment': 'His baseball infobox already shows up later down the article'},
#      {'revid': 1164107208,
#       'parentid': 1163203911,
#       'user': '2601:84:847E:AB70:7896:4A98:CADB:5F00',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2023-07-07T23:45:07Z',
#       'size': 88963,
#       'sha1': 'e158961d88400d1e8c27fe2d35d0538d5c5ef288',
#       'comment': ''},
#      {'revid': 1163203911,
#       'parentid': 1161646513,
#       'user': 'RevMSWIE500',
#       'userid': 17450822,
#       'timestamp': '2023-07-03T14:29:21Z',
#       'size': 88967,
#       'sha1': '069acdc994b793f61d09ab35917b049d80dc8322',
#       'comment': '/* Professional football career */'},
#      {'revid': 1161646513,
#       'parentid': 1161558650,
#       'user': 'Thetreesarespeakingtome',
#       'userid': 43107864,
#       'timestamp': '2023-06-24T02:46:08Z',
#       'size': 88902,
#       'sha1': 'ddae66b398c2c97beb6c4e2eaea514be426f9d51',
#       'comment': ''},
#      {'revid': 1161558650,
#       'parentid': 1161496106,
#       'user': 'Unger Woo',
#       'userid': 42912601,
#       'timestamp': '2023-06-23T14:19:26Z',
#       'size': 88954,
#       'sha1': 'fca6be8961965cad16986876f888c1428171d238',
#       'comment': ''},
#      {'revid': 1161496106,
#       'parentid': 1161398308,
#       'user': '2601:600:9180:6AD0:85C4:BB8B:CA31:9E0C',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2023-06-23T02:45:51Z',
#       'size': 88902,
#       'sha1': 'ddae66b398c2c97beb6c4e2eaea514be426f9d51',
#       'comment': '/* San Francisco 49ers */Fixed typo'},
#      {'revid': 1161398308,
#       'parentid': 1160895505,
#       'user': '204.141.104.115',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2023-06-22T12:41:51Z',
#       'size': 88902,
#       'sha1': 'c6eb450245ea911fff63960095c748668e4c0115',
#       'comment': '/* Personal life */'},
#      {'revid': 1160895505,
#       'parentid': 1160805939,
#       'user': '2600:6C58:7E00:F454:3CF2:85CE:F65C:EE97',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2023-06-19T10:57:47Z',
#       'size': 88905,
#       'sha1': '8c55830310a36ab7d638802df0f353dbc47c378d',
#       'comment': '/* Personal life */'},
#      {'revid': 1160805939,
#       'parentid': 1160733640,
#       'user': 'Stonecold415',
#       'userid': 33118295,
#       'timestamp': '2023-06-18T22:14:01Z',
#       'size': 88906,
#       'sha1': 'eebce6d0fba96559b7e9c1f5e4ecdcc8d867f176',
#       'comment': ''},
#      {'revid': 1160733640,
#       'parentid': 1160733475,
#       'user': 'Thetreesarespeakingtome',
#       'userid': 43107864,
#       'timestamp': '2023-06-18T12:18:25Z',
#       'size': 88902,
#       'sha1': '09572755465b876c0b6a35b507a095ed23feb926',
#       'comment': ''},
#      {'revid': 1160733475,
#       'parentid': 1160522113,
#       'user': 'Thetreesarespeakingtome',
#       'userid': 43107864,
#       'timestamp': '2023-06-18T12:17:03Z',
#       'size': 88905,
#       'sha1': 'd6070c25d41cb763b2ad7640d8797814eb7b4ac4',
#       'comment': ''},
#      {'revid': 1160522113,
#       'parentid': 1160521786,
#       'user': '24.126.176.241',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2023-06-17T01:13:59Z',
#       'size': 88410,
#       'sha1': '25e89bed439e7d07c10db063178ee32d5fdccfdd',
#       'comment': ''},
#      {'revid': 1160521786,
#       'parentid': 1160330164,
#       'user': '24.126.176.241',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2023-06-17T01:10:11Z',
#       'size': 88418,
#       'sha1': '29b09cb9ab3e17e7ae3d8446427b447389ece2fc',
#       'comment': 'Corrected where he went to school. He went to  Florida State University not Talladega College'},
#      {'revid': 1160330164,
#       'parentid': 1160105967,
#       'user': 'TDKR Chicago 101',
#       'userid': 17209722,
#       'timestamp': '2023-06-15T20:13:13Z',
#       'size': 88410,
#       'sha1': '25e89bed439e7d07c10db063178ee32d5fdccfdd',
#       'comment': ''},
#      {'revid': 1160105967,
#       'parentid': 1158717605,
#       'user': 'Citation bot',
#       'userid': 7903804,
#       'timestamp': '2023-06-14T12:58:03Z',
#       'size': 88400,
#       'sha1': 'ed4c36a46fa130ebabbd3a5e9c3c85fad35747b3',
#       'comment': 'Alter: template type, date. Add: date, work, magazine. Removed parameters. Some additions/deletions were parameter name changes. | [[WP:UCB|Use this bot]]. [[WP:DBUG|Report bugs]]. | Suggested by Smasongarrison | Linked from User:Smasongarrison/sandbox | #UCB_webform_linked 2084/3849'},
#      {'revid': 1158717605,
#       'parentid': 1158076789,
#       'user': 'Rhett8',
#       'userid': 35553153,
#       'timestamp': '2023-06-05T20:39:48Z',
#       'size': 88278,
#       'sha1': 'e62ea4e40447140bd2138f71e5c3fd134f815342',
#       'comment': ''},
#      {'revid': 1158076789,
#       'parentid': 1158076615,
#       'user': 'Marist72',
#       'userid': 31096180,
#       'timestamp': '2023-06-01T21:03:30Z',
#       'size': 88280,
#       'sha1': '03f66826b3c7e3ef0e503a6d4c396a0c9f976a66',
#       'comment': ''},
#      {'revid': 1158076615,
#       'parentid': 1158076481,
#       'user': 'Marist72',
#       'userid': 31096180,
#       'timestamp': '2023-06-01T21:01:58Z',
#       'size': 88279,
#       'sha1': '59c979180832685e284a6f15281adc2f1b52f4f3',
#       'comment': ''},
#      {'revid': 1158076481,
#       'parentid': 1157851264,
#       'user': 'Marist72',
#       'userid': 31096180,
#       'timestamp': '2023-06-01T21:00:51Z',
#       'size': 88312,
#       'sha1': 'd8ac9e065792c19150cc60623f472f19f706b7ea',
#       'comment': ''},
#      {'revid': 1157851264,
#       'parentid': 1157795061,
#       'user': '87.52.108.94',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2023-05-31T10:41:37Z',
#       'size': 88279,
#       'sha1': '3ffb0943c022e4a2fdb9b57d7356f72b4f9ed2fe',
#       'comment': ''},
#      {'revid': 1157795061,
#       'parentid': 1157794997,
#       'user': 'Marist72',
#       'userid': 31096180,
#       'timestamp': '2023-05-31T01:15:10Z',
#       'size': 88279,
#       'sha1': '5a6e6f728f524bb2a6cf225c2eae9329264b8dec',
#       'comment': ''},
#      {'revid': 1157794997,
#       'parentid': 1157794954,
#       'user': 'Marist72',
#       'userid': 31096180,
#       'timestamp': '2023-05-31T01:14:37Z',
#       'size': 88246,
#       'sha1': '2047a0326f97dbbb35a5b144d4ff6fdcbb45a00f',
#       'comment': ''},
#      {'revid': 1157794954,
#       'parentid': 1157794822,
#       'user': 'Marist72',
#       'userid': 31096180,
#       'timestamp': '2023-05-31T01:14:10Z',
#       'size': 88253,
#       'sha1': 'b252fd57ae3f2ac8e6aaef156658723ba9b38559',
#       'comment': ''},
#      {'revid': 1157794822,
#       'parentid': 1157794740,
#       'user': 'Marist72',
#       'userid': 31096180,
#       'timestamp': '2023-05-31T01:12:44Z',
#       'size': 88286,
#       'sha1': '5a48775d78da6335c15e980a1f8cb0ce8ec78a82',
#       'comment': ''},
#      {'revid': 1157794740,
#       'parentid': 1157770189,
#       'user': 'Marist72',
#       'userid': 31096180,
#       'timestamp': '2023-05-31T01:11:44Z',
#       'size': 88285,
#       'sha1': '4b488c7cc3d62c7ebbdea7287bb1cc9d9b392496',
#       'comment': ''},
#      {'revid': 1157770189,
#       'parentid': 1157643010,
#       'user': 'William Avery',
#       'userid': 1398,
#       'timestamp': '2023-05-30T21:08:40Z',
#       'size': 88246,
#       'sha1': 'dd04f6d5340b3627b76dcbb0ec1ff64c50c98c4a',
#       'comment': "[[MOS:']]; [[MOS:STRAIGHT]]"},
#      {'revid': 1157643010,
#       'parentid': 1157642679,
#       'user': 'Larry Hockett',
#       'userid': 15977090,
#       'timestamp': '2023-05-30T01:08:18Z',
#       'size': 88252,
#       'sha1': '547d4c994b15dea0c795ecb7a371e261ab8d3bd7',
#       'comment': 'Undid revision 1157642679 by [[Special:Contributions/Coltonk664|Coltonk664]] ([[User talk:Coltonk664|talk]]) found in the next sentence'},
#      {'revid': 1157642679,
#       'parentid': 1157617316,
#       'user': 'Coltonk664',
#       'userid': 46008183,
#       'timestamp': '2023-05-30T01:04:01Z',
#       'size': 88268,
#       'sha1': '361808240d70b63da42c3af819c80fce642ad372',
#       'comment': ''},
#      {'revid': 1157617316,
#       'parentid': 1157617145,
#       'user': 'Discospinster',
#       'userid': 82432,
#       'timestamp': '2023-05-29T20:48:35Z',
#       'size': 88252,
#       'sha1': '547d4c994b15dea0c795ecb7a371e261ab8d3bd7',
#       'comment': 'Reverted edits by [[Special:Contributions/216.227.45.107|216.227.45.107]] ([[User talk:216.227.45.107|talk]]) ([[WP:HG|HG]]) (3.4.12)'},
#      {'revid': 1157617145,
#       'parentid': 1157617052,
#       'user': '216.227.45.107',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2023-05-29T20:47:23Z',
#       'size': 88238,
#       'sha1': 'c8aed5451e27cd9c9203c7b01183ebcd46a3a13b',
#       'comment': ''},
#      {'revid': 1157617052,
#       'parentid': 1157173208,
#       'user': '216.227.45.107',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2023-05-29T20:46:45Z',
#       'size': 88239,
#       'sha1': '93ac113700c0caecd97def8b33e45579df9974c1',
#       'comment': ''},
#      {'revid': 1157173208,
#       'parentid': 1157173142,
#       'user': 'Illusion Flame',
#       'userid': 45416752,
#       'timestamp': '2023-05-26T20:44:29Z',
#       'size': 88252,
#       'sha1': '547d4c994b15dea0c795ecb7a371e261ab8d3bd7',
#       'comment': 'Reverted edits by [[Special:Contributions/166.181.85.131|166.181.85.131]] ([[User talk:166.181.85.131|talk]]) ([[WP:AntiVandal|AV]])'},
#      {'revid': 1157173142,
#       'parentid': 1157147447,
#       'user': '166.181.85.131',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2023-05-26T20:44:05Z',
#       'size': 88247,
#       'sha1': 'f8dd7a3d09eedb8a5d20251249b524080d2b2ed6',
#       'comment': ''},
#      {'revid': 1157147447,
#       'parentid': 1156641307,
#       'user': 'Red Director',
#       'userid': 1261736,
#       'timestamp': '2023-05-26T17:01:40Z',
#       'size': 88252,
#       'sha1': '547d4c994b15dea0c795ecb7a371e261ab8d3bd7',
#       'comment': '/* Personal life */ source date'},
#      {'revid': 1156641307,
#       'parentid': 1154541607,
#       'user': '2601:545:8200:51C0:61E2:4A3C:3E41:A390',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2023-05-23T21:39:06Z',
#       'size': 88242,
#       'sha1': '3a4c07f91abbddbe9c14d6bad1ce4e323b2456ce',
#       'comment': '/* Professional football career */'},
#      {'revid': 1154541607,
#       'parentid': 1154541430,
#       'user': 'Dwanyewest',
#       'userid': 475718,
#       'timestamp': '2023-05-13T05:16:20Z',
#       'size': 88242,
#       'sha1': 'de317f91968012213827d10e7af1a79b041f3633',
#       'comment': '/* Other business and entertainment ventures */'},
#      {'revid': 1154541430,
#       'parentid': 1154241875,
#       'user': 'Dwanyewest',
#       'userid': 475718,
#       'timestamp': '2023-05-13T05:14:30Z',
#       'size': 88025,
#       'sha1': '211e34c18bec500a0c738d8dc71f93e503dbf839',
#       'comment': '/* Other business and entertainment ventures */'},
#      {'revid': 1154241875,
#       'parentid': 1153775821,
#       'user': '174.193.113.205',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2023-05-11T04:55:10Z',
#       'size': 88021,
#       'sha1': '9d0067af015e05a781b720ce532926841706cd2a',
#       'comment': 'Fixed grammar'},
#      {'revid': 1153775821,
#       'parentid': 1153653359,
#       'user': 'ElliAWB',
#       'userid': 41052350,
#       'timestamp': '2023-05-08T07:31:51Z',
#       'size': 88018,
#       'sha1': '4786f7c012effc365596df3e3e7d43decebd47fd',
#       'comment': 'Disambiguating links to [[National League]] (link changed to [[National League (baseball)]]) using [[User:Qwertyytrewqqwerty/DisamAssist|DisamAssist]].'},
#      {'revid': 1153653359,
#       'parentid': 1153500956,
#       'user': 'GreenC bot',
#       'userid': 27823944,
#       'timestamp': '2023-05-07T14:46:15Z',
#       'size': 88007,
#       'sha1': 'dd27e11b5816e0ec576327dbdb7147f46dd0d632',
#       'comment': 'Reformat 1 archive link. [[User:GreenC/WaybackMedic_2.5|Wayback Medic 2.5]]'},
#      {'revid': 1153500956,
#       'parentid': 1153500774,
#       'user': 'Bluerules',
#       'userid': 5294038,
#       'timestamp': '2023-05-06T19:58:09Z',
#       'size': 87894,
#       'sha1': '4f107e2e09e58d169b530e25dac44ec25e3878cb',
#       'comment': 'Sanders played multiple sports in college.'},
#      {'revid': 1153500774,
#       'parentid': 1153500514,
#       'user': 'Bluerules',
#       'userid': 5294038,
#       'timestamp': '2023-05-06T19:56:31Z',
#       'size': 87932,
#       'sha1': 'ce834d02a7e3ca3197dfd1c3a1c383b1802a4d04',
#       'comment': ''},
#      {'revid': 1153500514,
#       'parentid': 1153324238,
#       'user': 'Bluerules',
#       'userid': 5294038,
#       'timestamp': '2023-05-06T19:54:39Z',
#       'size': 87952,
#       'sha1': '52a702983a81922e5ca67c1510657d42e8c7d2a7',
#       'comment': 'Cleaning up edits that resulted in duplicated hyperlinks and unnecessary details.'},
#      {'revid': 1153324238,
#       'parentid': 1153169981,
#       'user': '73.53.135.28',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2023-05-05T16:02:40Z',
#       'size': 88867,
#       'sha1': '8a9d5a52f66c182a1c5c627fd5b4dfad5784d0bc',
#       'comment': '/* Draft and Atlanta Falcons */'},
#      {'revid': 1153169981,
#       'parentid': 1153165709,
#       'user': 'CodeTalker',
#       'userid': 4490355,
#       'timestamp': '2023-05-04T16:35:19Z',
#       'size': 88867,
#       'sha1': '30e9c405adc928573ba49d3af6cc4eedc8212830',
#       'comment': 'Reverted 1 edit by [[Special:Contributions/73.53.135.28|73.53.135.28]] ([[User talk:73.53.135.28|talk]])'},
#      {'revid': 1153165709,
#       'parentid': 1153157579,
#       'user': '73.53.135.28',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2023-05-04T16:04:15Z',
#       'size': 88866,
#       'sha1': 'd0c54bdc79d729665331d60ccb72cbf04d4db166',
#       'comment': '/* College career */'},
#      {'revid': 1153157579,
#       'parentid': 1153090176,
#       'user': 'Sjw75',
#       'userid': 20079180,
#       'timestamp': '2023-05-04T15:06:22Z',
#       'size': 88867,
#       'sha1': '30e9c405adc928573ba49d3af6cc4eedc8212830',
#       'comment': '/* Defensive/Special team statistics */'},
#      {'revid': 1153090176,
#       'parentid': 1153018249,
#       'user': '49ersBelongInSanFrancisco',
#       'userid': 20398877,
#       'timestamp': '2023-05-04T04:58:45Z',
#       'size': 88868,
#       'sha1': 'd11514a994161bb2d42329e5de1e0691587f77b0',
#       'comment': 'Reverted 1 edit by [[Special:Contributions/104.232.4.194|104.232.4.194]] ([[User talk:104.232.4.194|talk]]) to last revision by 2600:8805:1920:4C00:796D:998C:D479:3BA1'},
#      {'revid': 1153018249,
#       'parentid': 1152776100,
#       'user': '104.232.4.194',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2023-05-03T18:22:12Z',
#       'size': 88867,
#       'sha1': '9994841039db40d7725102ebf708e0315dcb2f90',
#       'comment': ''},
#      {'revid': 1152776100,
#       'parentid': 1152776063,
#       'user': '2600:8805:1920:4C00:796D:998C:D479:3BA1',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2023-05-02T07:20:32Z',
#       'size': 88868,
#       'sha1': 'd11514a994161bb2d42329e5de1e0691587f77b0',
#       'comment': ''},
#      {'revid': 1152776063,
#       'parentid': 1152775923,
#       'user': '2600:8805:1920:4C00:796D:998C:D479:3BA1',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2023-05-02T07:20:05Z',
#       'size': 88866,
#       'sha1': '4b02f684c8d21931334fd3ced07756e9c8caf472',
#       'comment': ''},
#      {'revid': 1152775923,
#       'parentid': 1152083806,
#       'user': '2600:8805:1920:4C00:796D:998C:D479:3BA1',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2023-05-02T07:17:56Z',
#       'size': 88869,
#       'sha1': '8b0237bbaa5a7b9da6d46a23db892a22e4054e35',
#       'comment': '/* Defensive/Special team statistics */'},
#      {'revid': 1152083806,
#       'parentid': 1152065628,
#       'user': 'Randy Kryn',
#       'userid': 4796325,
#       'timestamp': '2023-04-28T02:41:27Z',
#       'size': 88868,
#       'sha1': 'ec9c612900f417cb7095b2d5ceddfbaf9625e8e5',
#       'comment': "full name and link to the hall of fame, added 'cornerback' and a bridge edit"},
#      {'revid': 1152065628,
#       'parentid': 1152065449,
#       'user': 'Randy Kryn',
#       'userid': 4796325,
#       'timestamp': '2023-04-28T00:04:24Z',
#       'size': 88875,
#       'sha1': '3f7f38b145afcfd60b1b3118f4ee2076af05b2ab',
#       'comment': '/* College career */ moved image to the right (Wikipedia preferred location especially if the subject is looking into the text)'},
#      {'revid': 1152065449,
#       'parentid': 1151673505,
#       'user': 'Randy Kryn',
#       'userid': 4796325,
#       'timestamp': '2023-04-28T00:02:53Z',
#       'size': 88880,
#       'sha1': 'ff452bb9d4c4d9aecbce19105fabf2a1c942ae61',
#       'comment': 'edits to lead (his NFL career would take precedence over his college coaching so mentioned his Hall of Fame membership in first sentence)'},
#      {'revid': 1151673505,
#       'parentid': 1151618080,
#       'user': '2600:4040:B425:A400:88BB:10EC:3771:1329',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2023-04-25T14:17:12Z',
#       'size': 88897,
#       'sha1': 'b4059c18a19ba815f53ba3600bc76852aea3e97a',
#       'comment': ''},
#      {'revid': 1151618080,
#       'parentid': 1151617701,
#       'user': 'Leiwang7',
#       'userid': 36909700,
#       'timestamp': '2023-04-25T04:20:35Z',
#       'size': 88897,
#       'sha1': '003a603a8efa3284444ab3399ac4678da8e2b3e8',
#       'comment': 'Modified my earlier edit'},
#      {'revid': 1151617701,
#       'parentid': 1151311274,
#       'user': 'Leiwang7',
#       'userid': 36909700,
#       'timestamp': '2023-04-25T04:16:00Z',
#       'size': 88763,
#       'sha1': 'e3284618c999c15337f885a3214307a422798691',
#       'comment': 'Removed reference to Sanders time at Jackson State at lead paragraph'},
#      {'revid': 1151311274,
#       'parentid': 1151311243,
#       'user': '2601:282:2180:9C30:6177:4C1E:ED4:6CD7',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2023-04-23T06:50:07Z',
#       'size': 88806,
#       'sha1': '39bcfae8e19650f7d56fda98621e3d18cfe4724f',
#       'comment': ''},
#      {'revid': 1151311243,
#       'parentid': 1151227772,
#       'user': '2601:282:2180:9C30:6177:4C1E:ED4:6CD7',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2023-04-23T06:49:36Z',
#       'size': 88805,
#       'sha1': '3f421b5d607745ae3bf151f629a43c22c87be022',
#       'comment': ''},
#      {'revid': 1151227772,
#       'parentid': 1151095819,
#       'user': '128.138.65.129',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2023-04-22T18:03:02Z',
#       'size': 88806,
#       'sha1': '39bcfae8e19650f7d56fda98621e3d18cfe4724f',
#       'comment': '/* Defensive/Special team statistics */'},
#      {'revid': 1151095819,
#       'parentid': 1149685671,
#       'user': 'NJTANK999',
#       'userid': 45777163,
#       'timestamp': '2023-04-21T21:51:04Z',
#       'size': 88806,
#       'sha1': '17e97183ec5d7c29bf938d037f28db5023f3ae3a',
#       'comment': '/* External links */'},
#      {'revid': 1149685671,
#       'parentid': 1149093073,
#       'user': '204.210.149.68',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2023-04-13T20:00:31Z',
#       'size': 88774,
#       'sha1': 'cc72b931a9414840751588af7723307bf59cd92d',
#       'comment': '/* Toronto Blue Jays */'},
#      {'revid': 1149093073,
#       'parentid': 1148591248,
#       'user': 'Oluwasegu',
#       'userid': 42266293,
#       'timestamp': '2023-04-10T04:32:00Z',
#       'size': 88777,
#       'sha1': 'a0090de2be4fa485a96c1fc02c960d3795092dc9',
#       'comment': 'duplicate --> baseball infobox already provided'},
#      {'revid': 1148591248,
#       'parentid': 1147951902,
#       'user': '71.179.15.250',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2023-04-07T03:29:16Z',
#       'size': 89753,
#       'sha1': '4f9a60bdddcd5170633c9e5e8f99786ec648c14d',
#       'comment': ''},
#      {'revid': 1147951902,
#       'parentid': 1147942113,
#       'user': 'Meters',
#       'userid': 3632083,
#       'timestamp': '2023-04-03T06:10:55Z',
#       'size': 89753,
#       'sha1': '5016a55a253025726c39bc102c0a4bc8b6b89abc',
#       'comment': 'Undid revision 1147942113 by [[Special:Contributions/Sharkdogdaughter|Sharkdogdaughter]] ([[User talk:Sharkdogdaughter|talk]])  no mention of this in the article'},
#      {'revid': 1147942113,
#       'parentid': 1147394210,
#       'user': 'Sharkdogdaughter',
#       'userid': 45178978,
#       'timestamp': '2023-04-03T04:48:01Z',
#       'size': 89786,
#       'sha1': '376c417280c9ad32ef9f20cb7f798f6ec137748d',
#       'comment': '/* External links */'},
#      {'revid': 1147394210,
#       'parentid': 1145380251,
#       'user': 'Mes tex',
#       'userid': 11124700,
#       'timestamp': '2023-03-30T17:29:51Z',
#       'size': 89753,
#       'sha1': '5016a55a253025726c39bc102c0a4bc8b6b89abc',
#       'comment': '/* College career */'},
#      {'revid': 1145380251,
#       'parentid': 1144426364,
#       'user': '2601:587:200:4EC0:E112:E828:651D:D462',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2023-03-18T21:20:07Z',
#       'size': 89813,
#       'sha1': 'a569bd0f51ed5aabbd8d42f7b8ebff0b0e696500',
#       'comment': ''},
#      {'revid': 1144426364,
#       'parentid': 1143747237,
#       'user': '2601:3C4:4303:5220:80E0:8F0C:8769:89AB',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2023-03-13T18:20:34Z',
#       'size': 89827,
#       'sha1': '7c66fd9b3c2ce7140781a4375ade0c968a138ae7',
#       'comment': ''},
#      {'revid': 1143747237,
#       'parentid': 1143747165,
#       'user': 'Wjp1134',
#       'userid': 26270848,
#       'timestamp': '2023-03-09T16:56:09Z',
#       'size': 89760,
#       'sha1': '0e7d4e2e346d5367d09677001a6c9767c30a694c',
#       'comment': '/* San Francisco 49ers */'},
#      {'revid': 1143747165,
#       'parentid': 1143747051,
#       'user': 'Wjp1134',
#       'userid': 26270848,
#       'timestamp': '2023-03-09T16:55:26Z',
#       'size': 89760,
#       'sha1': '61a8525451c9840f89dd10d574675d20b5d2b047',
#       'comment': '/* San Francisco 49ers */'},
#      {'revid': 1143747051,
#       'parentid': 1142240356,
#       'user': 'Wjp1134',
#       'userid': 26270848,
#       'timestamp': '2023-03-09T16:54:35Z',
#       'size': 89759,
#       'sha1': 'fa2dba6b2a2eaa3541be021b20b4fc791a7e1213',
#       'comment': '/* San Francisco 49ers */'},
#      {'revid': 1142240356,
#       'parentid': 1141783576,
#       'user': 'Bagumba',
#       'userid': 8005368,
#       'timestamp': '2023-03-01T08:04:59Z',
#       'size': 89595,
#       'sha1': 'e0f89baf4e37c1533c7cc4b501095fb0916a09c5',
#       'comment': '/* top */  [[MOS:CONTEXTBIO]]'},
#      {'revid': 1141783576,
#       'parentid': 1141398177,
#       'user': 'Sharkdogdaughter',
#       'userid': 45178978,
#       'timestamp': '2023-02-26T19:48:31Z',
#       'size': 89458,
#       'sha1': '35f3fc8c8c13336967174ad68cd7c22597433f56',
#       'comment': '/* External links */'},
#      {'revid': 1141398177,
#       'parentid': 1141398069,
#       'user': 'Koplimek',
#       'userid': 2360147,
#       'timestamp': '2023-02-24T21:40:35Z',
#       'size': 89422,
#       'sha1': 'c46970eaaf8274144a7858c1e01ffa9ce25b079e',
#       'comment': 'spruce up'},
#      {'revid': 1141398069,
#       'parentid': 1140861646,
#       'user': 'Koplimek',
#       'userid': 2360147,
#       'timestamp': '2023-02-24T21:39:50Z',
#       'size': 89422,
#       'sha1': '238ab68dbeff0a486a7e66dadc794edc869f4387',
#       'comment': 'nick name as player'},
#      {'revid': 1140861646,
#       'parentid': 1140153775,
#       'user': '68.129.242.41',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2023-02-22T03:45:19Z',
#       'size': 89401,
#       'sha1': 'f0d5edbe90f8076f4a120cfae51b568206decf06',
#       'comment': ''},
#      {'revid': 1140153775,
#       'parentid': 1138412820,
#       'user': 'Sergio Skol',
#       'userid': 36517939,
#       'timestamp': '2023-02-18T18:43:05Z',
#       'size': 89404,
#       'sha1': '38e00890242aed7a91f5c01f64a221d701824c01',
#       'comment': 'Undid revision 1138412820 by [[Special:Contributions/Nega95|Nega95]] ([[User talk:Nega95|talk]])'},
#      {'revid': 1138412820,
#       'parentid': 1138274152,
#       'user': 'Nega95',
#       'userid': 40287813,
#       'timestamp': '2023-02-09T15:06:12Z',
#       'size': 89363,
#       'sha1': 'daf05fa3ef737c1bb657059da08ac576390df3be',
#       'comment': ''},
#      {'revid': 1138274152,
#       'parentid': 1137843985,
#       'user': '2600:1016:B02D:BFA9:C8EC:84B5:F5BD:7DB3',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2023-02-08T21:01:36Z',
#       'size': 89404,
#       'sha1': '38e00890242aed7a91f5c01f64a221d701824c01',
#       'comment': '/* Atlanta Braves (1991–1994) */Atlanta Braves won the NL West in 1991, not the NL East'},
#      {'revid': 1137843985,
#       'parentid': 1137843759,
#       'user': 'Bharel',
#       'userid': 8123684,
#       'timestamp': '2023-02-06T19:01:28Z',
#       'size': 89383,
#       'sha1': '1def27f3a9a0ee75e147954eced2027afaa1416b',
#       'comment': 'Reverting edit(s) by [[Special:Contributions/104.244.141.69|104.244.141.69]] ([[User_talk:104.244.141.69|talk]]) to rev. 1137449953 by Bender the Bot: per [[WP:NPOV]] [[w:en:WP:RW|(RW 16.1)]]'},
#      {'revid': 1137843759,
#       'parentid': 1137449953,
#       'user': '104.244.141.69',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2023-02-06T19:00:44Z',
#       'size': 89494,
#       'sha1': '2975fa2f1cc95c8d8ec7ffcc192c7ffa3c5d2eb0',
#       'comment': '/* Baltimore Ravens */'},
#      {'revid': 1137449953,
#       'parentid': 1136986853,
#       'user': 'Bender the Bot',
#       'userid': 28903366,
#       'timestamp': '2023-02-04T18:50:54Z',
#       'size': 89383,
#       'sha1': '1def27f3a9a0ee75e147954eced2027afaa1416b',
#       'comment': '/* Leon Sandcastle */HTTP to HTTPS for [[Wayback Machine]], replaced: http://web.archive.org/ → https://web.archive.org/'},
#      {'revid': 1136986853,
#       'parentid': 1136986823,
#       'user': 'Lightoil',
#       'userid': 25524306,
#       'timestamp': '2023-02-02T04:35:46Z',
#       'size': 89382,
#       'sha1': 'b8669433d918a8aedba5e962fcbbe0a5c112d051',
#       'comment': '[[WP:ROLLBACK|Reverted]] edits by [[Special:Contributions/174.51.20.220|174.51.20.220]] ([[User talk:174.51.20.220|talk]]) to last revision by Extraordinary2: disruptive edits'},
#      {'revid': 1136986823,
#       'parentid': 1136146621,
#       'user': '174.51.20.220',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2023-02-02T04:35:28Z',
#       'size': 89393,
#       'sha1': 'cbff35005341087bb6e17daa971bdb999159a28b',
#       'comment': ''},
#      {'revid': 1136146621,
#       'parentid': 1136145584,
#       'user': 'Extraordinary2',
#       'userid': 44287047,
#       'timestamp': '2023-01-28T23:46:22Z',
#       'size': 89382,
#       'sha1': 'b8669433d918a8aedba5e962fcbbe0a5c112d051',
#       'comment': 'degree'},
#      {'revid': 1136145584,
#       'parentid': 1136145067,
#       'user': 'Extraordinary2',
#       'userid': 44287047,
#       'timestamp': '2023-01-28T23:38:06Z',
#       'size': 89424,
#       'sha1': '835ae568b272828acac54c14fa729aca2206a451',
#       'comment': 'relief'},
#      {'revid': 1136145067,
#       'parentid': 1136143805,
#       'user': 'Extraordinary2',
#       'userid': 44287047,
#       'timestamp': '2023-01-28T23:34:01Z',
#       'size': 89449,
#       'sha1': '466f3a8ac77e3ac0e6f312eb5d43cb28e73462ec',
#       'comment': 'waivers'},
#      {'revid': 1136143805,
#       'parentid': 1136143705,
#       'user': 'Extraordinary2',
#       'userid': 44287047,
#       'timestamp': '2023-01-28T23:24:41Z',
#       'size': 89450,
#       'sha1': 'e3cfb6588adc57094b443ec2837280fcc687f2fe',
#       'comment': 'caption'},
#      {'revid': 1136143705,
#       'parentid': 1136143035,
#       'user': 'Extraordinary2',
#       'userid': 44287047,
#       'timestamp': '2023-01-28T23:23:53Z',
#       'size': 89451,
#       'sha1': '6f4e540117fb489bb84562624709e26a628d0d01',
#       'comment': 'play'},
#      {'revid': 1136143035,
#       'parentid': 1136140493,
#       'user': 'Extraordinary2',
#       'userid': 44287047,
#       'timestamp': '2023-01-28T23:18:42Z',
#       'size': 89465,
#       'sha1': '7116954bc0ebfdead60c0de528b965b6158729b4',
#       'comment': 'adjective'},
#      {'revid': 1136140493,
#       'parentid': 1136140400,
#       'user': 'Materialscientist',
#       'userid': 7852030,
#       'timestamp': '2023-01-28T23:01:48Z',
#       'size': 89467,
#       'sha1': '7c3106f0f5a97d04311e12623b2522131b1277a9',
#       'comment': 'Reverted edits by [[Special:Contributions/Extraordinary2|Extraordinary2]] ([[User talk:Extraordinary2|talk]]) ([[WP:HG|HG]]) (3.4.11)'},
#      {'revid': 1136140400,
#       'parentid': 1135294756,
#       'user': 'Extraordinary2',
#       'userid': 44287047,
#       'timestamp': '2023-01-28T23:01:14Z',
#       'size': 84195,
#       'sha1': 'adf5ef907a48f520950d4ffbb89c0577464a2e42',
#       'comment': 'program'},
#      {'revid': 1135294756,
#       'parentid': 1135274142,
#       'user': 'Imzadi1979',
#       'userid': 488581,
#       'timestamp': '2023-01-23T20:09:57Z',
#       'size': 89467,
#       'sha1': '7c3106f0f5a97d04311e12623b2522131b1277a9',
#       'comment': 'Filled in 7 bare reference(s) with reFill 2, [[Wikipedia:MOSNUMscript|script]]-assisted date audit and style fixes per [[MOS:NUM]]; harmonize whitespace in citation templates (using [[w:en:User:Waldir/formatcitations.js|Regex citation formatter]])'},
#      {'revid': 1135274142,
#       'parentid': 1135214925,
#       'user': 'Bradleysballs',
#       'userid': 36392306,
#       'timestamp': '2023-01-23T17:36:53Z',
#       'size': 87468,
#       'sha1': '59be706d3e89025e3c9ce6da41ae65f0fb437319',
#       'comment': 'copy edit'},
#      {'revid': 1135214925,
#       'parentid': 1135214497,
#       'user': 'BrianYox',
#       'userid': 45218569,
#       'timestamp': '2023-01-23T09:39:32Z',
#       'size': 87398,
#       'sha1': 'ddbfad516d1cb9b2a89ee08f16b89ff7f2eca387',
#       'comment': '/* Dallas Cowboys */Content and references'},
#      {'revid': 1135214497,
#       'parentid': 1135118361,
#       'user': 'BrianYox',
#       'userid': 45218569,
#       'timestamp': '2023-01-23T09:33:57Z',
#       'size': 87249,
#       'sha1': '0f6a5912f373f50dc3070ab6bd51cfdc1e3dbac8',
#       'comment': 'Content, references'},
#      {'revid': 1135118361,
#       'parentid': 1135113586,
#       'user': '2604:5500:C009:FD00:1C87:C7B6:A9C3:9150',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2023-01-22T19:07:44Z',
#       'size': 86886,
#       'sha1': '832789f6ea0c1172bf3585818323bed05a9563e7',
#       'comment': '/* College career */ Fixed spelling'},
#      {'revid': 1135113586,
#       'parentid': 1134984635,
#       'user': 'Sergio Skol',
#       'userid': 36517939,
#       'timestamp': '2023-01-22T18:30:55Z',
#       'size': 86885,
#       'sha1': 'e47ff8df9333ddd50c72933301ce763ef2a4b0f0',
#       'comment': ''},
#      {'revid': 1134984635,
#       'parentid': 1134984548,
#       'user': '2601:648:8105:46B0:2505:B41E:48F5:252E',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2023-01-21T22:14:36Z',
#       'size': 86333,
# ...
#      {'revid': 1116255103,
#       'parentid': 1116233169,
#       'user': 'Rikster2',
#       'userid': 3077044,
#       'timestamp': '2022-10-15T17:00:26Z',
#       'size': 82153,
#       'sha1': 'a434c4151e07a7070700c51cfff746171a1d7287',
#       'comment': ''},
#      {'revid': 1116233169,
#       'parentid': 1116168538,
#       'user': 'Hunterb212',
#       'userid': 34135342,
#       'timestamp': '2022-10-15T14:31:43Z',
#       'size': 82134,
#       'sha1': '1cff5915a2359a68c93ceb9e66fb1c29e8154335',
#       'comment': 'Undid revision 1116161706 by [[Special:Contributions/Pats6XChamps|Pats6XChamps]] ([[User talk:Pats6XChamps|talk]]) per NFL.com'},
#      {'revid': 1116168538,
#       'parentid': 1116161706,
#       'user': 'ZappaOMatic',
#       'userid': 16349307,
#       'timestamp': '2022-10-15T05:22:24Z',
#       'size': 82134,
#       'sha1': '6a0b272d89a26adb6aa6000f5de4d5d25f544eb5',
#       'comment': 'Tweaks'},
#      {'revid': 1116161706,
#       'parentid': 1116047140,
#       'user': 'Pats6XChamps',
#       'userid': 44189360,
#       'timestamp': '2022-10-15T04:16:16Z',
#       'size': 82130,
#       'sha1': 'e2a6bbd4aa55bb59a4732b051734bbc3f09c6921',
#       'comment': 'Source: https://www.pro-football-reference.com/players/S/SandDe00.htm'},
#      {'revid': 1116047140,
#       'parentid': 1115974863,
#       'user': 'Hunterb212',
#       'userid': 34135342,
#       'timestamp': '2022-10-14T14:33:58Z',
#       'size': 82130,
#       'sha1': 'b65fad578502aaef38fa2678655224f519259da0',
#       'comment': 'Undid revision 1115944579 by [[Special:Contributions/Pats6XChamps|Pats6XChamps]] ([[User talk:Pats6XChamps|talk]]) unsourced'},
#      {'revid': 1115974863,
#       'parentid': 1115944579,
#       'user': 'RHodnett',
#       'userid': 4015130,
#       'timestamp': '2022-10-14T04:29:31Z',
#       'size': 82130,
#       'sha1': 'e2a6bbd4aa55bb59a4732b051734bbc3f09c6921',
#       'comment': '/* Media appearances and pop culture fame */ Linked to article about Nick Saban.'},
#      {'revid': 1115944579,
#       'parentid': 1115590394,
#       'user': 'Pats6XChamps',
#       'userid': 44189360,
#       'timestamp': '2022-10-14T00:46:26Z',
#       'size': 82126,
#       'sha1': 'cb22db77b2fd3f88b5313162aa3fa45030977bd6',
#       'comment': ''},
#      {'revid': 1115590394,
#       'parentid': 1115523965,
#       'user': 'Bringingthewood',
#       'userid': 43682176,
#       'timestamp': '2022-10-12T06:14:52Z',
#       'size': 82126,
#       'sha1': 'a88ad26ae2914ca241acbb27bea3e0c4d42cd084',
#       'comment': 'removed caps'},
#      {'revid': 1115523965,
#       'parentid': 1115523789,
#       'user': 'Lol1VNIO',
#       'userid': 42594286,
#       'timestamp': '2022-10-11T22:18:19Z',
#       'size': 82126,
#       'sha1': '7dad68f966013ce1ab3ddf30a85a11edab7241a0',
#       'comment': 'Reverted edits by [[Special:Contributions/2600:1702:2DC0:CF80:F158:2BD7:4097:24C1|2600:1702:2DC0:CF80:F158:2BD7:4097:24C1]] ([[User talk:2600:1702:2DC0:CF80:F158:2BD7:4097:24C1|talk]]) ([[WP:HG|HG]]) (3.4.10)'},
#      {'revid': 1115523789,
#       'parentid': 1115523576,
#       'user': '2600:1702:2DC0:CF80:F158:2BD7:4097:24C1',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2022-10-11T22:17:05Z',
#       'size': 82119,
#       'sha1': '62951b43bc2dbd8f62dbdd0266f33e575760ecaf',
#       'comment': ''},
#      {'revid': 1115523576,
#       'parentid': 1115523423,
#       'user': '2600:1702:2DC0:CF80:F158:2BD7:4097:24C1',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2022-10-11T22:15:24Z',
#       'size': 82126,
#       'sha1': '33476076151206da801057e8e9b4b57609fc02ea',
#       'comment': ''},
#      {'revid': 1115523423,
#       'parentid': 1115523390,
#       'user': 'Lol1VNIO',
#       'userid': 42594286,
#       'timestamp': '2022-10-11T22:14:17Z',
#       'size': 82126,
#       'sha1': '7dad68f966013ce1ab3ddf30a85a11edab7241a0',
#       'comment': 'Reverted edits by [[Special:Contributions/2600:1702:2DC0:CF80:F158:2BD7:4097:24C1|2600:1702:2DC0:CF80:F158:2BD7:4097:24C1]] ([[User talk:2600:1702:2DC0:CF80:F158:2BD7:4097:24C1|talk]]) ([[WP:HG|HG]]) (3.4.10)'},
#      {'revid': 1115523390,
#       'parentid': 1115492825,
#       'user': '2600:1702:2DC0:CF80:F158:2BD7:4097:24C1',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2022-10-11T22:14:02Z',
#       'size': 82125,
#       'sha1': '4892a8187af405df4c28fbbf65cd7c7fb17b0f09',
#       'comment': ''},
#      {'revid': 1115492825,
#       'parentid': 1115331384,
#       'user': 'Lbr123',
#       'userid': 1036062,
#       'timestamp': '2022-10-11T19:05:32Z',
#       'size': 82126,
#       'sha1': '7dad68f966013ce1ab3ddf30a85a11edab7241a0',
#       'comment': ''},
#      {'revid': 1115331384,
#       'parentid': 1115331325,
#       'user': 'ClueBot NG',
#       'userid': 13286072,
#       'timestamp': '2022-10-10T23:16:40Z',
#       'size': 82122,
#       'sha1': 'db37c3a68b9b0edc80f19b0c9944e9f48a4cf620',
#       'comment': 'Reverting possible vandalism by [[Special:Contribs/2600:1700:9A98:3080:F996:3B1F:4E3:94E8|2600:1700:9A98:3080:F996:3B1F:4E3:94E8]] to version by DavidBrooks. [[WP:CBFP|Report False Positive?]] Thanks, [[WP:CBNG|ClueBot NG]]. (4181034) (Bot)'},
#      {'revid': 1115331325,
#       'parentid': 1115135965,
#       'user': '2600:1700:9A98:3080:F996:3B1F:4E3:94E8',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2022-10-10T23:16:15Z',
#       'size': 82115,
#       'sha1': '32136ff5cc2e6899c92c9a419b64f594fe17092b',
#       'comment': 'Nickname'},
#      {'revid': 1115135965,
#       'parentid': 1115135603,
#       'user': 'DavidBrooks',
#       'userid': 55225,
#       'timestamp': '2022-10-10T00:18:57Z',
#       'size': 82122,
#       'sha1': 'db37c3a68b9b0edc80f19b0c9944e9f48a4cf620',
#       'comment': 'Reverted 1 edit by [[Special:Contributions/2600:1700:8540:3110:DCDE:B31F:EAA2:3D|2600:1700:8540:3110:DCDE:B31F:EAA2:3D]] ([[User talk:2600:1700:8540:3110:DCDE:B31F:EAA2:3D|talk]]): Unsourced'},
#      {'revid': 1115135603,
#       'parentid': 1115129275,
#       'user': '2600:1700:8540:3110:DCDE:B31F:EAA2:3D',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2022-10-10T00:16:06Z',
#       'size': 82198,
#       'sha1': 'a439f941ea8a36fbcfa2f67b1e0e1e839cf8ee2b',
#       'comment': ''},
#      {'revid': 1115129275,
#       'parentid': 1115129102,
#       'user': 'Muboshgu',
#       'userid': 602857,
#       'timestamp': '2022-10-09T23:34:27Z',
#       'size': 82122,
#       'sha1': 'db37c3a68b9b0edc80f19b0c9944e9f48a4cf620',
#       'comment': 'Changing [[Wikipedia:Short description|short description]] from "American athlete, sports analyst, and football coach (born 1967)" to "American football player and coach (born 1967)"'},
#      {'revid': 1115129102,
#       'parentid': 1115126941,
#       'user': 'Muboshgu',
#       'userid': 602857,
#       'timestamp': '2022-10-09T23:33:32Z',
#       'size': 82140,
#       'sha1': '3c70b7f340bea931a494edd5f945692a02f27261',
#       'comment': 'Reverted edits by [[Special:Contribs/Barnettnicholas5|Barnettnicholas5]] ([[User talk:Barnettnicholas5|talk]]) to last version by Zzuuzz'},
#      {'revid': 1115126941,
#       'parentid': 1115093721,
#       'user': 'Barnettnicholas5',
#       'userid': 44640317,
#       'timestamp': '2022-10-09T23:19:43Z',
#       'size': 82170,
#       'sha1': '63e916b079e20ac445717c1f0ae55bbee1fa1eec',
#       'comment': ''},
#      {'revid': 1115093721,
#       'parentid': 1115093652,
#       'user': 'Zzuuzz',
#       'userid': 365454,
#       'timestamp': '2022-10-09T19:56:34Z',
#       'size': 82140,
#       'sha1': '3c70b7f340bea931a494edd5f945692a02f27261',
#       'comment': 'Reverted edits by [[Special:Contribs/Myleshsjs|Myleshsjs]] ([[User talk:Myleshsjs|talk]]) to last version by Wjacob29'},
#      {'revid': 1115093652,
#       'parentid': 1115018891,
#       'user': 'Myleshsjs',
#       'userid': 44639607,
#       'timestamp': '2022-10-09T19:56:09Z',
#       'size': 82165,
#       'sha1': '64509ddc641df2b5b828f0af199ada1d968e9548',
#       'comment': ''},
#      {'revid': 1115018891,
#       'parentid': 1115018701,
#       'user': 'Wjacob29',
#       'userid': 41372748,
#       'timestamp': '2022-10-09T12:19:34Z',
#       'size': 82140,
#       'sha1': '3c70b7f340bea931a494edd5f945692a02f27261',
#       'comment': ''},
#      {'revid': 1115018701,
#       'parentid': 1114418601,
#       'user': 'Wjacob29',
#       'userid': 41372748,
#       'timestamp': '2022-10-09T12:18:06Z',
#       'size': 82140,
#       'sha1': '0c97c57ed3d8d7c05f4a0c24fd13268f5ca2fb6c',
#       'comment': '/* Head coaching record */'},
#      {'revid': 1114418601,
#       'parentid': 1112992148,
#       'user': 'Bagumba',
#       'userid': 8005368,
#       'timestamp': '2022-10-06T11:50:10Z',
#       'size': 82140,
#       'sha1': 'b20efeb00982f0d4fc0c75982d64bdc0354e974d',
#       'comment': "/* top */ he's still an American and not a former coach"},
#      {'revid': 1112992148,
#       'parentid': 1112923004,
#       'user': '2600:8802:C01:4D00:B123:BFCC:5518:3458',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2022-09-29T04:34:58Z',
#       'size': 82112,
#       'sha1': '431f86fb50f96de419e0e880c4a93dfedd569e76',
#       'comment': ''},
#      {'revid': 1112923004,
#       'parentid': 1112922472,
#       'user': '2600:1004:B12D:55B6:A195:DB16:1B95:3847',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2022-09-28T20:08:51Z',
#       'size': 82116,
#       'sha1': 'ed4feff2313fd0a76977d48659b58843079e25bd',
#       'comment': ''},
#      {'revid': 1112922472,
#       'parentid': 1112922283,
#       'user': '2600:1004:B12D:55B6:A195:DB16:1B95:3847',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2022-09-28T20:05:29Z',
#       'size': 82147,
#       'sha1': 'b1abc9789b68f097f13774f8e9c7075946a96c78',
#       'comment': ''},
#      {'revid': 1112922283,
#       'parentid': 1112841193,
#       'user': '2600:1004:B12D:55B6:A195:DB16:1B95:3847',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2022-09-28T20:04:14Z',
#       'size': 82152,
#       'sha1': '972afbb2278be51bc609ea3f72327480fa9b7a1d',
#       'comment': ''},
#      {'revid': 1112841193,
#       'parentid': 1112755995,
#       'user': '2600:1700:16E0:3F40:E05A:62C0:6302:E95F',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2022-09-28T11:10:05Z',
#       'size': 82152,
#       'sha1': 'fc5bc1e1be6e7aea309d112654d11e06c4a14891',
#       'comment': 'Changed coaching time frame at Jackson State from 2020-2022 to 2020-present'},
#      {'revid': 1112755995,
#       'parentid': 1112755453,
#       'user': '2601:CD:400:BB80:C1E4:3D00:7856:784D',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2022-09-27T23:31:54Z',
#       'size': 82149,
#       'sha1': 'b72ea6cda4477853feb0d556e4363059b28a37ce',
#       'comment': 'trying to undo auburn nonsense'},
#      {'revid': 1112755453,
#       'parentid': 1112750921,
#       'user': '2601:CD:400:BB80:C1E4:3D00:7856:784D',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2022-09-27T23:26:58Z',
#       'size': 82233,
#       'sha1': '25f8225c7655de8ec047e3b829b23873e5706f4a',
#       'comment': 'Undid revision 1112750395 by [[Special:Contributions/2600:1700:2ED3:911F:B8BB:C8B0:6E49:6FF6|2600:1700:2ED3:911F:B8BB:C8B0:6E49:6FF6]] ([[User talk:2600:1700:2ED3:911F:B8BB:C8B0:6E49:6FF6|talk]])'},
#      {'revid': 1112750921,
#       'parentid': 1112750670,
#       'user': '2600:1700:2ED3:911F:B8BB:C8B0:6E49:6FF6',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2022-09-27T22:44:26Z',
#       'size': 82230,
#       'sha1': '9fffb32a685b6c4226740da5b76ca9bf452c6f59',
#       'comment': ''},
#      {'revid': 1112750670,
#       'parentid': 1112750395,
#       'user': '2600:1700:2ED3:911F:B8BB:C8B0:6E49:6FF6',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2022-09-27T22:42:05Z',
#       'size': 82135,
#       'sha1': '29f25fe92b5aceda5841799f566e16fab3016004',
#       'comment': ''},
#      {'revid': 1112750395,
#       'parentid': 1112432134,
#       'user': '2600:1700:2ED3:911F:B8BB:C8B0:6E49:6FF6',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2022-09-27T22:39:29Z',
#       'size': 82134,
#       'sha1': '441c5bd401f29e7b12c6a20180ec174f107731c0',
#       'comment': ''},
#      {'revid': 1112432134,
#       'parentid': 1112432017,
#       'user': 'Wjacob29',
#       'userid': 41372748,
#       'timestamp': '2022-09-26T09:09:00Z',
#       'size': 82137,
#       'sha1': 'cb01be63ac904c7e3804845266589150caf9dc70',
#       'comment': ''},
#      {'revid': 1112432017,
#       'parentid': 1112431987,
#       'user': 'Wjacob29',
#       'userid': 41372748,
#       'timestamp': '2022-09-26T09:07:54Z',
#       'size': 82137,
#       'sha1': '4f22d2bec32a4d2a65b2e5d0f99b1c54242b272d',
#       'comment': '/* Head coaching record */'},
#      {'revid': 1112431987,
#       'parentid': 1111944373,
#       'user': 'Wjacob29',
#       'userid': 41372748,
#       'timestamp': '2022-09-26T09:07:35Z',
#       'size': 82137,
#       'sha1': '191ea817b38a51de98ff248966b0211abf7ac8e6',
#       'comment': '/* Head coaching record */'},
#      {'revid': 1111944373,
#       'parentid': 1111876409,
#       'user': 'Wp bh726',
#       'userid': 9207897,
#       'timestamp': '2022-09-23T20:43:31Z',
#       'size': 82137,
#       'sha1': 'b0c101caa6f774ea8f398bd455a75054b9e04f8a',
#       'comment': 'Fixed inaccurate trade detail'},
#      {'revid': 1111876409,
#       'parentid': 1111606936,
#       'user': 'Keith D',
#       'userid': 2278355,
#       'timestamp': '2022-09-23T12:04:00Z',
#       'size': 82132,
#       'sha1': 'acfe3d498253910161c20b3da475864a48d12b81',
#       'comment': 'Not an author'},
#      {'revid': 1111606936,
#       'parentid': 1111262642,
#       'user': 'Failedattempt',
#       'userid': 31060007,
#       'timestamp': '2022-09-21T22:35:25Z',
#       'size': 82327,
#       'sha1': 'd9aca74e94d62f9e8f59fd12bcb8f0c85feadbe9',
#       'comment': '/* Professional baseball career */'},
#      {'revid': 1111262642,
#       'parentid': 1111211955,
#       'user': '76.188.222.89',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2022-09-20T03:05:18Z',
#       'size': 80494,
#       'sha1': 'dac6fe18d728c46e78cdca26f47ff500e1735f59',
#       'comment': '/* Head coaching record */'},
#      {'revid': 1111211955,
#       'parentid': 1111208626,
#       'user': 'AnomieBOT',
#       'userid': 7611264,
#       'timestamp': '2022-09-19T21:53:21Z',
#       'size': 80494,
#       'sha1': '2b199c47a8064bb271d915011c920043cc7ab136',
#       'comment': 'Dating maintenance tags: {{Cn}}'},
#      {'revid': 1111208626,
#       'parentid': 1111208571,
#       'user': 'Muboshgu',
#       'userid': 602857,
#       'timestamp': '2022-09-19T21:32:41Z',
#       'size': 80474,
#       'sha1': '6d0fba42b7ace05f3c9e19d5f19eb5a372ea5e54',
#       'comment': '/* High school */'},
#      {'revid': 1111208571,
#       'parentid': 1111208462,
#       'user': 'Muboshgu',
#       'userid': 602857,
#       'timestamp': '2022-09-19T21:32:14Z',
#       'size': 80464,
#       'sha1': '545ad75c04d982165ec09f4822ff4790f4177ae9',
#       'comment': '/* Washington Redskins */'},
#      {'revid': 1111208462,
#       'parentid': 1111208026,
#       'user': 'Muboshgu',
#       'userid': 602857,
#       'timestamp': '2022-09-19T21:31:36Z',
#       'size': 80484,
#       'sha1': 'bced7aeea5e6cb17fcf542b6161a13bdf099dd44',
#       'comment': 'Undid revision 1111208026 by [[Special:Contributions/2600:1004:B234:69F3:5414:8C45:365F:894F|2600:1004:B234:69F3:5414:8C45:365F:894F]] ([[User talk:2600:1004:B234:69F3:5414:8C45:365F:894F|talk]]) that introduces a typo'},
#      {'revid': 1111208026,
#       'parentid': 1111177329,
#       'user': '2600:1004:B234:69F3:5414:8C45:365F:894F',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2022-09-19T21:28:27Z',
#       'size': 80488,
#       'sha1': '163fc73aa45100e7a02c70cd62b442768929c143',
#       'comment': '/* Washington Redskins */Fixed typo'},
#      {'revid': 1111177329,
#       'parentid': 1110879810,
#       'user': '98.243.249.17',
#       'anon': '',
#       'userid': 0,
#       'timestamp': '2022-09-19T18:03:57Z',
#       'size': 80484,
#       'sha1': 'bced7aeea5e6cb17fcf542b6161a13bdf099dd44',
#       'comment': '/* Offensive statistics */'},
#      {'revid': 1110879810,
#       'parentid': 1110408711,
#       'user': 'Failedattempt',
#       'userid': 31060007,
#       'timestamp': '2022-09-18T04:44:23Z',
#       'size': 80484,
#       'sha1': 'b419de4102539feaa186e32e1ed26e6a27a670b6',
#       'comment': ''}]}}}}
